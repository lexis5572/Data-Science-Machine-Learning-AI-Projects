# %% [markdown]
# - File sources : https://www.kaggle.com/datasets/arashnic/lung-dataset/data

# %%
# %%time

import warnings
warnings.filterwarnings('ignore')
# Out:
# CPU times: user 36 µs, sys: 14 µs, total: 50 µs
# Wall time: 62 µs

# %%
# %%time

import wave

# Open the audio file
with wave.open('/kaggle/input/lung-dataset/Audio Files/BP101_Asthma,E W,P L M,12,F.wav', 'rb') as wf:
    sample_rate = wf.getframerate()  # Get sample rate calculation
    number_of_frames = wf.getnframes()  # Optional: Get number of frames
    print(f'Sample Rate: {sample_rate}')
# Out:
# Sample Rate: 4000
# CPU times: user 1.48 ms, sys: 2.82 ms, total: 4.29 ms
# Wall time: 12.1 ms

# %%
# %%time

import tensorflow as tf
import tensorflow_hub as hub

# Load the YAMNet model from TensorFlow Hub
yamnet_model = hub.load('https://www.kaggle.com/models/google/yamnet/TensorFlow2/yamnet/1')
# Out:
# CPU times: user 7.01 s, sys: 1.35 s, total: 8.36 s
# Wall time: 15 s

# %%
# %%time

import os 
import librosa 
import numpy as np 
import soundfile as sf 
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd 
import tensorflow as tf 
import tensorflow_hub as hub 
import io 
import csv 

# Function to extract class names from the model's class_map_path
def class_names_from_csv(class_map_csv_text):
    """Returns list of class names corresponding to score vector."""
    class_map_csv = io.StringIO(class_map_csv_text)
    # Skip the header
    csv_reader = csv.reader(class_map_csv)
    next(csv_reader)
    class_names = [display_name for (class_index, mid, display_name) in csv_reader]
    return class_names

# Load class names from the model's class_map_path
class_map_path = yamnet_model.class_map_path().numpy()
class_names = class_names_from_csv(tf.io.read_file(class_map_path).numpy().decode('utf-8'))

def preprocess_audio(audio_file_path, target_sr=4000):
    """ Preprocess audio file for YAMNet input.
    
    Parameters:
    -----------
    audio_file_path : str
        Path to audio file
    target_sr : int
        Target sampling rate (YAMNet expects 16kHz)

    Returns:
    --------
    numpy array : Preprocessed audio waveform
    """
    try:
        # Load and resample audio
        waveform, sr = librosa.load(audio_file_path, sr=target_sr)
        # Ensure minimum duration (1 second)
        if len(waveform) < target_sr:
            waveform = np.pad(waveform, (0, target_sr - len(waveform)))
        return waveform
    except Exception as e:
        print(f"Error processing {audio_file_path}: {str(e)}")
        return None

def classify_audio_file(audio_file_path):
    """ Classify audio file using YAMNet.
    
    Parameters:
    -----------
    audio_file_path : str
        Path to audio file

    Returns:
    --------
    tuple : (predicted_class, confidence_score)
    """
    try:
        # Preprocess audio
        waveform = preprocess_audio(audio_file_path, target_sr=4000)  # YAMNet expects kHz
        if waveform is None:
            return None, None
        # Run the model
        scores, embeddings, spectrogram = yamnet_model(waveform)
        # Get the predicted class and confidence
        class_scores = scores.numpy().mean(axis=0)
        predicted_class_idx = np.argmax(class_scores)
        confidence_score = class_scores[predicted_class_idx]
        # Get class name from the loaded class names
        predicted_class = class_names[predicted_class_idx]
        return predicted_class, confidence_score
    except Exception as e:
        print(f"Error classifying {audio_file_path}: {str(e)}")
        return None, None

def process_audio_directory(audio_directory, limit=500):
    """ Process all audio files in a directory.
    
    Parameters:
    -----------
    audio_directory : str
        Path to directory containing audio files
    limit : int
        Maximum number of files to process

    Returns:
    --------
    list : List of (filename, prediction, confidence) tuples
    """
    results = []
    # Get list of audio files, now .wav format
    audio_files = [f for f in os.listdir(audio_directory) if f.lower().endswith('.wav')][:limit]
    # Process each file
    for audio_file in audio_files:
        audio_file_path = os.path.join(audio_directory, audio_file)
        predicted_class, confidence = classify_audio_file(audio_file_path)
        if predicted_class is not None:
            results.append((audio_file, predicted_class, confidence))
        print(f"Processed: {audio_file} - Class: {predicted_class} - Confidence: {confidence:.3f}")
    return results

def plot_results(results):
    """ Plot classification results.
    
    Parameters:
    -----------
    results : list
        List of (filename, prediction, confidence) tuples
    """
    if not results:
        print("No results to plot.")
        return
    
    # Extract predictions and confidences
    predictions = [r[1] for r in results]
    confidences = [r[2] for r in results]

    # Plot distribution of predictions
    plt.figure(figsize=(15, 5))
    
    # Prediction distribution
    plt.subplot(1, 2, 1)
    pred_counts = pd.Series(predictions).value_counts()
    sns.barplot(x=pred_counts.index, y=pred_counts.values)
    plt.xticks(rotation=90, ha='right')
    plt.title('Distribution of Predictions')
    
    # Confidence distribution
    plt.subplot(1, 2, 2)
    sns.histplot(confidences, bins=20)
    plt.title('Distribution of Confidence Scores')

    plt.tight_layout()
    plt.show()

# Main execution
if __name__ == "__main__":
    # Directory containing the audio files
    audio_directory = '/kaggle/input/lung-dataset/Audio Files'
    # Process audio files
    print("Processing audio files...")
    results = process_audio_directory(audio_directory, limit=500)

    # Create DataFrame
    if results:
        df_results = pd.DataFrame(results, columns=['filename', 'prediction', 'confidence'])
        # Print summary statistics
        print("\nSummary Statistics:")
        print("-" * 50)
        print(f"Total files processed: {len(df_results)}")
        print("\nPrediction counts:")
        print(df_results['prediction'].value_counts().head())
        print("\nConfidence score statistics:")
        print(df_results['confidence'].describe())
        # Plot results
        plot_results(results)
        
        # Save results confidence score is 0.1 or higher
        df_filtered = df_results[df_results['confidence'] >= 0.1]
        # Save the filtered DataFrame to a CSV file
        output_csv_path = 'lung_disease_sounds.csv'
        df_filtered.to_csv(output_csv_path, index=False)
        print(f"Filtered results saved to {output_csv_path}")
    else:
        print("No audio files processed successfully.")
# Out:
# Processing audio files...
# Processed: EP76_N,N,A L U,31,M.wav - Class: Animal - Confidence: 0.111
# Processed: EP93_N,N,P R M,75,M.wav - Class: Noise - Confidence: 0.165
# Processed: BP13_Heart Failure,C,P L L,55,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.264
# Processed: BP23_Lung Fibrosis,Crep,P R L ,50,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.396
# Processed: EP67_heart failure,Crep,P R L ,24,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.395
# Processed: EP79_asthma,E W,A R U,46,M.wav - Class: Speech - Confidence: 0.289
# Processed: BP24_heart failure,Crep,P R L ,76,F.wav - Class: Stomach rumble - Confidence: 0.493
# Processed: DP32_N,N,A R L,30,M.wav - Class: Vehicle - Confidence: 0.228
# Processed: DP83_N,N,A R U,18,F.wav - Class: Vehicle - Confidence: 0.155
# Processed: EP58_asthma,E W,P L M,40,M.wav - Class: Outside, rural or natural - Confidence: 0.136
# Processed: BP50_N,N,P R L ,27,M.wav - Class: Sound effect - Confidence: 0.258
# Processed: DP36_pneumonia,Crep,P R M,36,F.wav - Class: Animal - Confidence: 0.353
# Processed: EP21_BRON,Crep,P R L ,20,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.349
# Processed: BP69_pneumonia,Bronchial,P R L ,64,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.347
# Processed: BP16_heart failure,C,P R U,56,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.399
# Processed: EP44_asthma,E W,P R U,40,M.wav - Class: Animal - Confidence: 0.147
# Processed: DP97_Asthma,E W,P R U,24,M.wav - Class: Vehicle - Confidence: 0.185
# Processed: EP94_N,N,P L L,24,M.wav - Class: Eruption - Confidence: 0.307
# Processed: BP109_N,N,P L M,26,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.374
# Processed: DP25_copd,E W,P L L,76,M.wav - Class: Gurgling - Confidence: 0.137
# Processed: DP105_Lung Fibrosis,Crep,A U R,44,M.wav - Class: Throbbing - Confidence: 0.152
# Processed: EP64_asthma,E W,P L U,60,M.wav - Class: Speech - Confidence: 0.138
# Processed: BP65_asthma,E W,P R L ,60,F.wav - Class: Eruption - Confidence: 0.236
# Processed: BP41_pneumonia,Crep,P R M,51,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.554
# Processed: EP106_Asthma,E W,P L U,45,F.wav - Class: Speech - Confidence: 0.227
# Processed: DP103_N,N,P R U,81,F.wav - Class: Vehicle - Confidence: 0.206
# Processed: BP38_Asthma,E W,P R M,38,M.wav - Class: Animal - Confidence: 0.560
# Processed: DP4_Heart Failure + Lung Fibrosis ,I C,P L R,72,F.wav - Class: Stomach rumble - Confidence: 0.310
# Processed: BP45_heart failure,Crep,P R L ,30,M.wav - Class: Eruption - Confidence: 0.324
# Processed: BP110_COPD,E W,P L L,62,M.wav - Class: Gurgling - Confidence: 0.304
# Processed: EP66_heart failure,Crep,P R L ,43,M.wav - Class: Wind - Confidence: 0.132
# Processed: DP24_heart failure,Crep,P R L ,76,F.wav - Class: Stomach rumble - Confidence: 0.436
# Processed: EP52_Lung Fibrosis,Crep,P L L,76,F.wav - Class: Vehicle - Confidence: 0.172
# Processed: DP107_Asthma,E W,P L U,59,F.wav - Class: Speech - Confidence: 0.173
# Processed: BP37_pneumonia,Crep,A R L,70,F.wav - Class: Music - Confidence: 0.324
# Processed: EP110_COPD,E W,P L L,62,M.wav - Class: Animal - Confidence: 0.500
# Processed: DP28_BRON,Crep,P L U,68,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.285
# Processed: DP10_Asthma,E W,P R U,59,M.wav - Class: Gurgling - Confidence: 0.254
# Processed: DP47_asthma,E W,P L M,60,M.wav - Class: Rumble - Confidence: 0.184
# Processed: DP84_N,N,A R U,65,F.wav - Class: Stomach rumble - Confidence: 0.308
# Processed: EP49_N,N,P R M,21,M.wav - Class: Wind - Confidence: 0.145
# Processed: DP40_heart failure,Crep,A R M,26,M.wav - Class: Animal - Confidence: 0.220
# Processed: BP39_heart failure,Crep,P R L ,67,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.413
# Processed: DP46_asthma,E W,P L U,41,F.wav - Class: Animal - Confidence: 0.453
# Processed: EP82_N,N,P L U,38,M.wav - Class: Throbbing - Confidence: 0.159
# Processed: EP4_Heart Failure + Lung Fibrosis ,I C,P L R,72,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.244
# Processed: DP55_asthma,E W,P R U,72,F.wav - Class: Gurgling - Confidence: 0.265
# Processed: EP41_pneumonia,Crep,P R M,51,M.wav - Class: Throbbing - Confidence: 0.219
# Processed: BP22_BRON,Crep,P R U,24,M.wav - Class: Vehicle - Confidence: 0.255
# Processed: BP18_pneumonia,C,P R U,57,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.711
# Processed: BP68_asthma,E W,P R L ,21,F.wav - Class: Eruption - Confidence: 0.259
# Processed: EP17_COPD,E W,A R M,57,M.wav - Class: Outside, rural or natural - Confidence: 0.151
# Processed: EP26_Lung Fibrosis,Crep,P,90,F.wav - Class: Animal - Confidence: 0.086
# Processed: BP63_COPD,E W,P R L ,58,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.212
# Processed: BP67_heart failure,Crep,P R L ,24,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.565
# Processed: DP13_Heart Failure,C,P L L,55,M.wav - Class: Stomach rumble - Confidence: 0.242
# Processed: BP77_Asthma,E W,A R L,40,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.802
# Processed: DP92_N,N,P L L ,43,M.wav - Class: Vehicle - Confidence: 0.280
# Processed: BP35_Asthma,E W,A R L,38,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.459
# Processed: EP78_Asthma,E W,P R M,20,M.wav - Class: Animal - Confidence: 0.343
# Processed: DP86_N,N,P R U,68,F.wav - Class: Throbbing - Confidence: 0.101
# Processed: DP109_N,N,P L M,26,M.wav - Class: Vehicle - Confidence: 0.222
# Processed: DP20_Asthma and lung fibrosis,C,A R M,90,M.wav - Class: Vehicle - Confidence: 0.200
# Processed: EP3_Asthma,I E W,P L L R,50,F.wav - Class: Animal - Confidence: 0.153
# Processed: EP30_N,N,P R M,18,F.wav - Class: Vehicle - Confidence: 0.171
# Processed: BP59_heart failure,Crep,P R L ,83,F.wav - Class: Vehicle - Confidence: 0.179
# Processed: BP4_Heart Failure + Lung Fibrosis ,I C,P L R,72,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.668
# Processed: DP87_N,N,P R M,72,M.wav - Class: Stomach rumble - Confidence: 0.113
# Processed: EP85_N,N,A R U,33,M.wav - Class: Wind - Confidence: 0.279
# Processed: DP82_N,N,P L U,38,M.wav - Class: Clip-clop - Confidence: 0.213
# Processed: BP70_N,N,P L U,52,F.wav - Class: Sound effect - Confidence: 0.219
# Processed: EP57_COPD,E W,P R L ,42,M.wav - Class: Outside, rural or natural - Confidence: 0.133
# Processed: EP99_N,N,P R M,50,M.wav - Class: Throbbing - Confidence: 0.387
# Processed: DP61_COPD,E W,P R L ,53,M.wav - Class: Stomach rumble - Confidence: 0.149
# Processed: DP8_Plueral Effusion,I C B,P L L,70,M.wav - Class: Stomach rumble - Confidence: 0.348
# Processed: DP95_N,N,P L M,18,M.wav - Class: Vehicle - Confidence: 0.129
# Processed: DP85_N,N,A R U,33,M.wav - Class: Outside, rural or natural - Confidence: 0.125
# Processed: BP71_N,N,P R U,36,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.865
# Processed: EP46_asthma,E W,P L U,41,F.wav - Class: Animal - Confidence: 0.380
# Processed: BP81_N,N,P L U,33,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.476
# Processed: BP60_heart failure,Crep,P L L,83,F.wav - Class: Stomach rumble - Confidence: 0.554
# Processed: BP106_Asthma,E W,P L U,45,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.168
# Processed: BP93_N,N,P R M,75,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.225
# Processed: EP6_Plueral Effusion,I C B,P L R,81,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.299
# Processed: DP14_Heart Failure,C,A R M,54,M.wav - Class: Vehicle - Confidence: 0.254
# Processed: EP62_COPD,E W,P L M,53,M.wav - Class: Wind - Confidence: 0.128
# Processed: BP55_asthma,E W,P R U,72,F.wav - Class: Gurgling - Confidence: 0.304
# Processed: EP101_Asthma,E W,P L M,12,F.wav - Class: Animal - Confidence: 0.203
# Processed: EP108_COPD,E W,P R L ,63,M.wav - Class: Throbbing - Confidence: 0.146
# Processed: DP56_asthma,E W,P R M,56,F.wav - Class: Clip-clop - Confidence: 0.176
# Processed: DP2_Asthma,E W,P L L R,52,F.wav - Class: Speech - Confidence: 0.078
# Processed: BP53_asthma,E W,P R M,72,F.wav - Class: Vehicle - Confidence: 0.158
# Processed: DP17_COPD,E W,A R M,57,M.wav - Class: Animal - Confidence: 0.242
# Processed: BP97_Asthma,E W,P R U,24,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.370
# Processed: DP104_Asthma,E W,P L U,45,F.wav - Class: Vehicle - Confidence: 0.244
# Processed: DP27_asthma,E W,P R M,53,F.wav - Class: Gurgling - Confidence: 0.225
# Processed: EP43_asthma,E W,P L M,15,M.wav - Class: Animal - Confidence: 0.501
# Processed: DP1_Asthma,I E W,P L L,70,M.wav - Class: Stomach rumble - Confidence: 0.326
# Processed: DP68_asthma,E W,P R L ,21,F.wav - Class: Vehicle - Confidence: 0.222
# Processed: EP56_asthma,E W,P R M,56,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.244
# Processed: DP72_N,N,P R U,24,F.wav - Class: Stomach rumble - Confidence: 0.306
# Processed: BP2_Asthma,E W,P L L R,52,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.422
# Processed: EP39_heart failure,Crep,P R L ,67,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.326
# Processed: DP108_COPD,E W,P R L ,63,M.wav - Class: Vehicle - Confidence: 0.139
# Processed: DP29_heart failure,Crep,P L L,57,M.wav - Class: Frog - Confidence: 0.274
# Processed: EP31_N,N,P L M,27,F.wav - Class: Throbbing - Confidence: 0.174
# Processed: EP29_heart failure,Crep,P L L,57,M.wav - Class: Animal - Confidence: 0.314
# Processed: DP26_Lung Fibrosis,Crep,P,90,F.wav - Class: Roaring cats (lions, tigers) - Confidence: 0.277
# Processed: DP22_BRON,Crep,P R U,24,M.wav - Class: Vehicle - Confidence: 0.223
# Processed: EP7_Heart Failure + COPD,I C E W,P L R,65,M.wav - Class: Animal - Confidence: 0.085
# Processed: EP102_N,N,P L L,41,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.245
# Processed: EP95_N,N,P L M,18,M.wav - Class: Throbbing - Confidence: 0.202
# Processed: DP73_N,N,P L L,32,M.wav - Class: Stomach rumble - Confidence: 0.202
# Processed: BP92_N,N,P L L ,43,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.215
# Processed: BP101_Asthma,E W,P L M,12,F.wav - Class: Gurgling - Confidence: 0.214
# Processed: EP84_N,N,A R U,65,F.wav - Class: Outside, rural or natural - Confidence: 0.125
# Processed: BP9_Asthma,E W,P R L ,59,M.wav - Class: Gurgling - Confidence: 0.294
# Processed: BP33_Asthma,E W,P R M,43,F.wav - Class: Animal - Confidence: 0.132
# Processed: EP63_COPD,E W,P R L ,58,F.wav - Class: Outside, rural or natural - Confidence: 0.135
# Processed: DP67_heart failure,Crep,P R L ,24,F.wav - Class: Stomach rumble - Confidence: 0.476
# Processed: BP21_BRON,Crep,P R L ,20,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.636
# Processed: DP58_asthma,E W,P L M,40,M.wav - Class: Stomach rumble - Confidence: 0.361
# Processed: DP30_N,N,P R M,18,F.wav - Class: Vehicle - Confidence: 0.235
# Processed: BP12_Asthma,E W,P L L,50,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.451
# Processed: BP26_Lung Fibrosis,Crep,P,90,F.wav - Class: Outside, rural or natural - Confidence: 0.110
# Processed: EP87_N,N,P R M,72,M.wav - Class: Throbbing - Confidence: 0.124
# Processed: DP6_Plueral Effusion,I C B,P L R,81,M.wav - Class: Stomach rumble - Confidence: 0.534
# Processed: DP71_N,N,P R U,36,M.wav - Class: Stomach rumble - Confidence: 0.230
# Processed: DP39_heart failure,Crep,P R L ,67,M.wav - Class: Stomach rumble - Confidence: 0.257
# Processed: BP44_asthma,E W,P R U,40,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.191
# Processed: DP69_pneumonia,Bronchial,P R L ,64,M.wav - Class: Stomach rumble - Confidence: 0.237
# Processed: DP44_asthma,E W,P R U,40,M.wav - Class: Animal - Confidence: 0.128
# Processed: BP20_Asthma and lung fibrosis,C,A R M,90,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.624
# Processed: DP23_Lung Fibrosis,Crep,P R L ,50,M.wav - Class: Gurgling - Confidence: 0.207
# Processed: EP74_N,N,P R M,74,M.wav - Class: Wind noise (microphone) - Confidence: 0.172
# Processed: BP83_N,N,A R U,18,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.379
# Processed: BP74_N,N,P R M,74,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.520
# Processed: BP61_COPD,E W,P R L ,53,M.wav - Class: Eruption - Confidence: 0.216
# Processed: DP74_N,N,P R M,74,M.wav - Class: Stomach rumble - Confidence: 0.155
# Processed: EP83_N,N,A R U,18,F.wav - Class: Wind - Confidence: 0.491
# Processed: EP37_pneumonia,Crep,A R L,70,F.wav - Class: Music - Confidence: 0.085
# Processed: EP88_N,N,A R U,29,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.394
# Processed: EP45_heart failure,Crep,P R L ,30,M.wav - Class: Wind noise (microphone) - Confidence: 0.137
# Processed: DP19_heart failure,C,P R U,70,F.wav - Class: Stomach rumble - Confidence: 0.704
# Processed: DP38_Asthma,E W,P R M,38,M.wav - Class: Animal - Confidence: 0.621
# Processed: DP43_asthma,E W,P L M,15,M.wav - Class: Animal - Confidence: 0.483
# Processed: EP60_heart failure,Crep,P L L,83,F.wav - Class: Stomach rumble - Confidence: 0.183
# Processed: DP54_heart failure,Crep,P R L ,73,F.wav - Class: Vehicle - Confidence: 0.316
# Processed: EP109_N,N,P L M,26,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.156
# Processed: EP61_COPD,E W,P R L ,53,M.wav - Class: Outside, rural or natural - Confidence: 0.117
# Processed: EP59_heart failure,Crep,P R L ,83,F.wav - Class: Sound effect - Confidence: 0.090
# Processed: BP28_BRON,Crep,P L U,68,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.928
# Processed: BP29_heart failure,Crep,P L L,57,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.392
# Processed: EP72_N,N,P R U,24,F.wav - Class: Outside, rural or natural - Confidence: 0.106
# Processed: EP54_heart failure,Crep,P R L ,73,F.wav - Class: Throbbing - Confidence: 0.268
# Processed: DP81_N,N,P L U,33,M.wav - Class: Stomach rumble - Confidence: 0.332
# Processed: DP34_heart failure,Crep,P R M,78,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.184
# Processed: DP48_N,N,P L U,31,M.wav - Class: Vehicle - Confidence: 0.195
# Processed: EP20_Asthma and lung fibrosis,C,A R M,90,M.wav - Class: Wind - Confidence: 0.239
# Processed: DP5_Heart Failure + COPD,I C E W,P L R ,71,M.wav - Class: Animal - Confidence: 0.199
# Processed: EP10_Asthma,E W,P R U,59,M.wav - Class: Speech - Confidence: 0.133
# Processed: BP86_N,N,P R U,68,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.691
# Processed: BP64_asthma,E W,P L U,60,M.wav - Class: Stomach rumble - Confidence: 0.560
# Processed: EP90_heart failure,Crep,P L M,74,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.203
# Processed: BP85_N,N,A R U,33,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.384
# Processed: BP87_N,N,P R M,72,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.358
# Processed: EP89_N,N,P L M,70,M.wav - Class: Throbbing - Confidence: 0.522
# Processed: BP99_N,N,P R M,50,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.602
# Processed: EP47_asthma,E W,P L M,60,M.wav - Class: Artillery fire - Confidence: 0.154
# Processed: EP28_BRON,Crep,P L U,68,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.245
# Processed: EP105_Lung Fibrosis,Crep,A U R,44,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.125
# Processed: EP55_asthma,E W,P R U,72,F.wav - Class: Clip-clop - Confidence: 0.188
# Processed: DP64_asthma,E W,P L U,60,M.wav - Class: Roaring cats (lions, tigers) - Confidence: 0.451
# Processed: EP16_heart failure,C,P R U,56,M.wav - Class: Artillery fire - Confidence: 0.254
# Processed: BP3_Asthma,I E W,P L L R,50,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.527
# Processed: BP51_N,N,P L M,30,M.wav - Class: Heart murmur - Confidence: 0.273
# Processed: DP57_COPD,E W,P R L ,42,M.wav - Class: Animal - Confidence: 0.202
# Processed: EP38_Asthma,E W,P R M,38,M.wav - Class: Animal - Confidence: 0.208
# Processed: EP111_COPD,E W,P R L ,51,M.wav - Class: Clip-clop - Confidence: 0.124
# Processed: DP80_asthma,E W,A L U,38,M.wav - Class: Animal - Confidence: 0.189
# Processed: EP91_asthma,E W,P R U,43,F.wav - Class: Animal - Confidence: 0.201
# Processed: DP33_Asthma,E W,P R M,43,F.wav - Class: Animal - Confidence: 0.367
# Processed: DP110_COPD,E W,P L L,62,M.wav - Class: Animal - Confidence: 0.570
# Processed: DP59_heart failure,Crep,P R L ,83,F.wav - Class: Stomach rumble - Confidence: 0.222
# Processed: EP86_N,N,P R U,68,F.wav - Class: Throbbing - Confidence: 0.476
# Processed: BP84_N,N,A R U,65,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.443
# Processed: EP96_N,N,P R L ,66,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.229
# Processed: EP33_Asthma,E W,P R M,43,F.wav - Class: Animal - Confidence: 0.153
# Processed: BP94_N,N,P L L,24,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.591
# Processed: EP70_N,N,P L U,52,F.wav - Class: Wind - Confidence: 0.264
# Processed: EP32_N,N,A R L,30,M.wav - Class: Wind noise (microphone) - Confidence: 0.207
# Processed: DP41_pneumonia,Crep,P R M,51,M.wav - Class: Animal - Confidence: 0.178
# Processed: DP79_asthma,E W,A R U,46,M.wav - Class: Animal - Confidence: 0.270
# Processed: BP95_N,N,P L M,18,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.431
# Processed: EP27_asthma,E W,P R M,53,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.124
# Processed: DP65_asthma,E W,P R L ,60,F.wav - Class: Stomach rumble - Confidence: 0.157
# Processed: DP12_Asthma,E W,P L L,50,F.wav - Class: Gurgling - Confidence: 0.281
# Processed: BP72_N,N,P R U,24,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.399
# Processed: DP15_Asthma,E W,P R U,49,F.wav - Class: Stomach rumble - Confidence: 0.307
# Processed: EP75_N,N,P L U,73,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.304
# Processed: BP17_COPD,E W,A R M,57,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.481
# Processed: EP19_heart failure,C,P R U,70,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.305
# Processed: DP42_heart failure,Crep,P L L,56,M.wav - Class: Vehicle - Confidence: 0.137
# Processed: DP70_N,N,P L U,52,F.wav - Class: Vehicle - Confidence: 0.309
# Processed: DP112_N,N,P L M,30,M.wav - Class: Rumble - Confidence: 0.127
# Processed: DP76_N,N,A L U,31,M.wav - Class: Throbbing - Confidence: 0.244
# Processed: DP45_heart failure,Crep,P R L ,30,M.wav - Class: Gurgling - Confidence: 0.290
# Processed: EP73_N,N,P L L,32,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.233
# Processed: BP27_asthma,E W,P R M,53,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.538
# Processed: EP69_pneumonia,Bronchial,P R L ,64,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.107
# Processed: BP36_pneumonia,Crep,P R M,36,F.wav - Class: Stomach rumble - Confidence: 0.500
# Processed: BP19_heart failure,C,P R U,70,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.436
# Processed: EP92_N,N,P L L ,43,M.wav - Class: Throbbing - Confidence: 0.165
# Processed: DP53_asthma,E W,P R M,72,F.wav - Class: Stomach rumble - Confidence: 0.138
# Processed: EP25_copd,E W,P L L,76,M.wav - Class: Livestock, farm animals, working animals - Confidence: 0.333
# Processed: DP37_pneumonia,Crep,A R L,70,F.wav - Class: Gurgling - Confidence: 0.142
# Processed: DP9_Asthma,E W,P R L ,59,M.wav - Class: Gurgling - Confidence: 0.294
# Processed: BP11_Heart Failure,C,P L L,53,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.417
# Processed: EP104_Asthma,E W,P L U,45,F.wav - Class: Wind noise (microphone) - Confidence: 0.201
# Processed: BP5_Heart Failure + COPD,I C E W,P L R ,71,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.266
# Processed: BP88_N,N,A R U,29,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.660
# Processed: DP93_N,N,P R M,75,M.wav - Class: Vehicle - Confidence: 0.345
# Processed: BP66_heart failure,Crep,P R L ,43,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.275
# Processed: BP58_asthma,E W,P L M,40,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.615
# Processed: DP77_Asthma,E W,A R L,40,M.wav - Class: Animal - Confidence: 0.282
# Processed: EP8_Plueral Effusion,I C B,P L L,70,M.wav - Class: Outside, rural or natural - Confidence: 0.097
# Processed: BP52_Lung Fibrosis,Crep,P L L,76,F.wav - Class: Eruption - Confidence: 0.393
# Processed: BP40_heart failure,Crep,A R M,26,M.wav - Class: Stomach rumble - Confidence: 0.543
# Processed: BP31_N,N,P L M,27,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.595
# Processed: EP36_pneumonia,Crep,P R M,36,F.wav - Class: Animal - Confidence: 0.300
# Processed: BP15_Asthma,E W,P R U,49,F.wav - Class: Stomach rumble - Confidence: 0.212
# Processed: BP73_N,N,P L L,32,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.403
# Processed: EP71_N,N,P R U,36,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.227
# Processed: BP105_Lung Fibrosis,Crep,A U R,44,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.814
# Processed: EP51_N,N,P L M,30,M.wav - Class: Outside, rural or natural - Confidence: 0.113
# Processed: EP42_heart failure,Crep,P L L,56,M.wav - Class: Boat, Water vehicle - Confidence: 0.225
# Processed: BP89_N,N,P L M,70,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.777
# Processed: BP56_asthma,E W,P R M,56,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.885
# Processed: BP108_COPD,E W,P R L ,63,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.191
# Processed: DP106_Asthma,E W,P L U,45,F.wav - Class: Speech - Confidence: 0.313
# Processed: EP5_Heart Failure + COPD,I C E W,P L R ,71,M.wav - Class: Explosion - Confidence: 0.182
# Processed: BP14_Heart Failure,C,A R M,54,M.wav - Class: Gurgling - Confidence: 0.218
# Processed: EP103_N,N,P R U,81,F.wav - Class: Gurgling - Confidence: 0.090
# Processed: DP62_COPD,E W,P L M,53,M.wav - Class: Stomach rumble - Confidence: 0.180
# Processed: DP91_asthma,E W,P R U,43,F.wav - Class: Animal - Confidence: 0.177
# Processed: BP25_copd,E W,P L L,76,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.183
# Processed: BP98_N,N,P L L,53,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.357
# Processed: BP104_Asthma,E W,P L U,45,F.wav - Class: Eruption - Confidence: 0.198
# Processed: BP103_N,N,P R U,81,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.288
# Processed: BP57_COPD,E W,P R L ,42,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.330
# Processed: EP40_heart failure,Crep,A R M,26,M.wav - Class: Wind noise (microphone) - Confidence: 0.206
# Processed: EP18_pneumonia,C,P R U,57,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.326
# Processed: EP23_Lung Fibrosis,Crep,P R L ,50,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.138
# Processed: EP77_Asthma,E W,A R L,40,M.wav - Class: Animal - Confidence: 0.111
# Processed: EP100_N,N,P R M,70,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.640
# Processed: DP90_heart failure,Crep,P L M,74,F.wav - Class: Stomach rumble - Confidence: 0.658
# Processed: DP101_Asthma,E W,P L M,12,F.wav - Class: Animal - Confidence: 0.521
# Processed: DP60_heart failure,Crep,P L L,83,F.wav - Class: Stomach rumble - Confidence: 0.341
# Processed: EP107_Asthma,E W,P L U,59,F.wav - Class: Artillery fire - Confidence: 0.248
# Processed: DP51_N,N,P L M,30,M.wav - Class: Stomach rumble - Confidence: 0.257
# Processed: EP48_N,N,P L U,31,M.wav - Class: Explosion - Confidence: 0.193
# Processed: BP46_asthma,E W,P L U,41,F.wav - Class: Explosion - Confidence: 0.170
# Processed: EP35_Asthma,E W,A R L,38,M.wav - Class: Boat, Water vehicle - Confidence: 0.158
# Processed: BP82_N,N,P L U,38,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.587
# Processed: DP63_COPD,E W,P R L ,58,F.wav - Class: Vehicle - Confidence: 0.215
# Processed: BP102_N,N,P L L,41,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.638
# Processed: BP96_N,N,P R L ,66,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.425
# Processed: DP31_N,N,P L M,27,F.wav - Class: Explosion - Confidence: 0.127
# Processed: BP75_N,N,P L U,73,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.505
# Processed: DP18_pneumonia,C,P R U,57,M.wav - Class: Horse - Confidence: 0.179
# Processed: EP68_asthma,E W,P R L ,21,F.wav - Class: Wind noise (microphone) - Confidence: 0.129
# Processed: BP107_Asthma,E W,P L U,59,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.465
# Processed: EP15_Asthma,E W,P R U,49,F.wav - Class: Animal - Confidence: 0.175
# Processed: BP80_asthma,E W,A L U,38,M.wav - Class: Explosion - Confidence: 0.200
# Processed: DP16_heart failure,C,P R U,56,M.wav - Class: Stomach rumble - Confidence: 0.260
# Processed: DP50_N,N,P R L ,27,M.wav - Class: Stomach rumble - Confidence: 0.305
# Processed: EP98_N,N,P L L,53,M.wav - Class: Outside, rural or natural - Confidence: 0.205
# Processed: DP49_N,N,P R M,21,M.wav - Class: Vehicle - Confidence: 0.215
# Processed: DP11_Heart Failure,C,P L L,53,M.wav - Class: Stomach rumble - Confidence: 0.659
# Processed: DP100_N,N,P R M,70,F.wav - Class: Animal - Confidence: 0.521
# Processed: DP21_BRON,Crep,P R L ,20,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.186
# Processed: DP75_N,N,P L U,73,F.wav - Class: Vehicle - Confidence: 0.112
# Processed: EP65_asthma,E W,P R L ,60,F.wav - Class: Explosion - Confidence: 0.187
# Processed: EP2_Asthma,E W,P L L R,52,F.wav - Class: Explosion - Confidence: 0.110
# Processed: DP96_N,N,P R L ,66,F.wav - Class: Stomach rumble - Confidence: 0.239
# Processed: DP94_N,N,P L L,24,M.wav - Class: Outside, rural or natural - Confidence: 0.147
# Processed: EP34_heart failure,Crep,P R M,78,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.446
# Processed: DP7_Heart Failure + COPD,I C E W,P L R,65,M.wav - Class: Stomach rumble - Confidence: 0.272
# Processed: EP9_Asthma,E W,P R L ,59,M.wav - Class: Animal - Confidence: 0.356
# Processed: DP99_N,N,P R M,50,M.wav - Class: Throbbing - Confidence: 0.133
# Processed: DP3_Asthma,I E W,P L L R,50,F.wav - Class: Stomach rumble - Confidence: 0.185
# Processed: BP47_asthma,E W,P L M,60,M.wav - Class: Sound effect - Confidence: 0.213
# Processed: BP91_asthma,E W,P R U,43,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.184
# Processed: EP11_Heart Failure,C,P L L,53,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.403
# Processed: EP50_N,N,P R L ,27,M.wav - Class: Explosion - Confidence: 0.144
# Processed: EP80_asthma,E W,A L U,38,M.wav - Class: Speech - Confidence: 0.358
# Processed: BP7_Heart Failure + COPD,I C E W,P L R,65,M.wav - Class: Stomach rumble - Confidence: 0.534
# Processed: BP79_asthma,E W,A R U,46,M.wav - Class: Stomach rumble - Confidence: 0.519
# Processed: BP90_heart failure,Crep,P L M,74,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.583
# Processed: DP78_Asthma,E W,P R M,20,M.wav - Class: Animal - Confidence: 0.273
# Processed: EP14_Heart Failure,C,A R M,54,M.wav - Class: Animal - Confidence: 0.390
# Processed: DP89_N,N,P L M,70,M.wav - Class: Vehicle - Confidence: 0.084
# Processed: BP62_COPD,E W,P L M,53,M.wav - Class: Eruption - Confidence: 0.211
# Processed: BP100_N,N,P R M,70,F.wav - Class: Gurgling - Confidence: 0.214
# Processed: BP78_Asthma,E W,P R M,20,M.wav - Class: Animal - Confidence: 0.238
# Processed: DP66_heart failure,Crep,P R L ,43,M.wav - Class: Outside, rural or natural - Confidence: 0.147
# Processed: EP1_Asthma,I E W,P L L,70,M.wav - Class: Livestock, farm animals, working animals - Confidence: 0.112
# Processed: EP22_BRON,Crep,P R U,24,M.wav - Class: Vehicle - Confidence: 0.339
# Processed: BP10_Asthma,E W,P R U,59,M.wav - Class: Gurgling - Confidence: 0.415
# Processed: BP1_Asthma,I E W,P L L,70,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.506
# Processed: BP49_N,N,P R M,21,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.323
# Processed: EP13_Heart Failure,C,P L L,55,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.111
# Processed: DP52_Lung Fibrosis,Crep,P L L,76,F.wav - Class: Rumble - Confidence: 0.145
# Processed: BP111_COPD,E W,P R L ,51,M.wav - Class: Eruption - Confidence: 0.265
# Processed: DP35_Asthma,E W,A R L,38,M.wav - Class: Vehicle - Confidence: 0.456
# Processed: BP76_N,N,A L U,31,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.823
# Processed: BP43_asthma,E W,P L M,15,M.wav - Class: Gurgling - Confidence: 0.137
# Processed: BP34_heart failure,Crep,P R M,78,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.591
# Processed: BP42_heart failure,Crep,P L L,56,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.509
# Processed: BP6_Plueral Effusion,I C B,P L R,81,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.721
# Processed: BP8_Plueral Effusion,I C B,P L L,70,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.236
# Processed: EP24_heart failure,Crep,P R L ,76,F.wav - Class: Animal - Confidence: 0.156
# Processed: DP98_N,N,P L L,53,M.wav - Class: Outside, rural or natural - Confidence: 0.148
# Processed: EP53_asthma,E W,P R M,72,F.wav - Class: Hum - Confidence: 0.087
# Processed: BP54_heart failure,Crep,P R L ,73,F.wav - Class: Heart sounds, heartbeat - Confidence: 0.204
# Processed: EP112_N,N,P L M,30,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.335
# Processed: BP112_N,N,P L M,30,M.wav - Class: Heart sounds, heartbeat - Confidence: 0.804
# Processed: EP12_Asthma,E W,P L L,50,F.wav - Class: Throbbing - Confidence: 0.162
# Processed: BP48_N,N,P L U,31,M.wav - Class: Eruption - Confidence: 0.317
# Processed: DP88_N,N,A R U,29,M.wav - Class: Vehicle - Confidence: 0.358
# Processed: DP102_N,N,P L L,41,M.wav - Class: Vehicle - Confidence: 0.115
# Processed: DP111_COPD,E W,P R L ,51,M.wav - Class: Gurgling - Confidence: 0.112
# Processed: BP30_N,N,P R M,18,F.wav - Class: Sound effect - Confidence: 0.208
# Processed: BP32_N,N,A R L,30,M.wav - Class: Eruption - Confidence: 0.263
# Processed: EP97_Asthma,E W,P R U,24,M.wav - Class: Explosion - Confidence: 0.143
# Processed: EP81_N,N,P L U,33,M.wav - Class: Throbbing - Confidence: 0.163
#
# Summary Statistics:
# --------------------------------------------------
# Total files processed: 336
#
# Prediction counts:
# prediction
# Heart sounds, heartbeat    100
# Animal                      42
# Stomach rumble              42
# Vehicle                     32
# Gurgling                    19
# Name: count, dtype: int64
#
# Confidence score statistics:
# count    336.000000
# mean       0.297898
# std        0.170729
# min        0.078434
# 25%        0.172609
# 50%        0.244374
# 75%        0.384359
# max        0.928452
# Name: confidence, dtype: float64
# Filtered results saved to lung_disease_sounds.csv
# CPU times: user 15.8 s, sys: 1.22 s, total: 17 s
# Wall time: 21.4 s
