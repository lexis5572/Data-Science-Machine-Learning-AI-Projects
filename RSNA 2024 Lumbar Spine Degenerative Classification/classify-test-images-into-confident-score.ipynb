# %% [markdown]
# - Convert dicom to jpg

# %%
# %%time

import os
from tqdm import tqdm
import pydicom
import numpy as np
from PIL import Image

# Define the parent directory containing subdirectories with DICOM files
parent_directory = '/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/test_images'
jpg_output_directory = '/kaggle/working/converted_test_images'

# Create output directory if it doesn't exist
os.makedirs(jpg_output_directory, exist_ok=True)

# Iterate through all subdirectories
for subdir, _, files in os.walk(parent_directory):
    for dicom_file in tqdm(files):
        dicom_path = os.path.join(subdir, dicom_file)
        if os.path.isfile(dicom_path) and dicom_file.endswith('.dcm'):
            # Read the DICOM file
            dicom_data = pydicom.dcmread(dicom_path)
            
            # Convert the DICOM pixel array to a PIL Image
            dicom_image = Image.fromarray(
                np.uint8(dicom_data.pixel_array / np.max(dicom_data.pixel_array) * 255)
            )
            
            # Save the image as a JPEG file
            relative_path = os.path.relpath(subdir, parent_directory)
            output_subdir = os.path.join(jpg_output_directory, relative_path)
            os.makedirs(output_subdir, exist_ok=True)
            jpg_filename = os.path.splitext(dicom_file)[0] + '.jpg'
            jpg_path = os.path.join(output_subdir, jpg_filename)
            dicom_image.save(jpg_path)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 25/25 [00:01<00:00, 24.27it/s]
# 100%|██████████| 47/47 [00:00<00:00, 95.02it/s]
# 100%|██████████| 25/25 [00:00<00:00, 40.72it/s]
# CPU times: user 1.7 s, sys: 143 ms, total: 1.84 s
# Wall time: 2.88 s

# %% [markdown]
# - Image classification using ResNet50

# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Load the ResNet50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet')

def preprocess_image(image_file_path, target_size=(224, 224)):
    """ Preprocess image for ResNet50 input.
    
    Parameters:
    -----------
    image_file_path : str
        Path to image file
    target_size : tuple
        Target size for the image (default is 224x224 for ResNet50)

    Returns:
    --------
    numpy array : Preprocessed image
    """
    try:
        # Load and preprocess the image
        image = load_img(image_file_path, target_size=target_size)
        image_array = img_to_array(image)
        image_array = np.expand_dims(image_array, axis=0)
        image_array = preprocess_input(image_array)
        return image_array
    except Exception as e:
        print(f"Error processing {image_file_path}: {str(e)}")
        return None

def classify_image_file(image_file_path):
    """ Classify image file using ResNet50.
    
    Parameters:
    -----------
    image_file_path : str
        Path to image file

    Returns:
    --------
    tuple : (predicted_class, confidence_score)
    """
    try:
        # Preprocess image
        image_array = preprocess_image(image_file_path)
        if image_array is None:
            return None, None
        # Run the model
        predictions = model.predict(image_array)
        # Decode predictions
        decoded_predictions = decode_predictions(predictions, top=1)[0][0]
        predicted_class = decoded_predictions[1]
        confidence_score = decoded_predictions[2]
        return predicted_class, confidence_score
    except Exception as e:
        print(f"Error classifying {image_file_path}: {str(e)}")
        return None, None

def process_images_in_directory(directory_path, limit=None):
    """ Process all images in a directory and its subdirectories.
    
    Parameters:
    -----------
    directory_path : str
        Path to the root directory containing image files
    limit : int, optional
        Maximum number of files to process (default is None, meaning no limit)

    Returns:
    --------
    list : List of (file_path, predicted_class, confidence_score) tuples
    """
    results = []
    count = 0
    for root, _, files in os.walk(directory_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                file_path = os.path.join(root, file)
                predicted_class, confidence_score = classify_image_file(file_path)
                if predicted_class is not None:
                    results.append((file_path, predicted_class, confidence_score))
                    print(f"Processed: {file_path} - Class: {predicted_class} - Confidence: {confidence_score:.3f}")
                count += 1
                if limit and count >= limit:
                    return results
    return results

# Example usage
if __name__ == "__main__":
    # Path to the root directory containing images
    root_directory = '/kaggle/working/converted_test_images'
    # Process images
    results = process_images_in_directory(root_directory, limit=500)

    # Print results
    for file_path, predicted_class, confidence_score in results:
        print(f"File: {file_path}, Class: {predicted_class}, Confidence: {confidence_score:.3f}")


# Save results to a CSV file
    if results:
        # Convert results to a DataFrame
        df_results = pd.DataFrame(results, columns=['file_path', 'predicted_class', 'confidence_score'])
        # Save DataFrame to a CSV file
        output_csv_path = 'image_test_rsna_2024_results.csv'
        df_results.to_csv(output_csv_path, index=False)
        print(f"Results saved to {output_csv_path}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/25.jpg - Class: fountain - Confidence: 0.646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/14.jpg - Class: trilobite - Confidence: 0.234
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/2.jpg - Class: mask - Confidence: 0.164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/16.jpg - Class: tractor - Confidence: 0.141
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/20.jpg - Class: prison - Confidence: 0.351
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/23.jpg - Class: mask - Confidence: 0.305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/24.jpg - Class: mask - Confidence: 0.361
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/8.jpg - Class: trilobite - Confidence: 0.384
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/15.jpg - Class: centipede - Confidence: 0.304
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/7.jpg - Class: mask - Confidence: 0.492
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/13.jpg - Class: trilobite - Confidence: 0.466
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/9.jpg - Class: nail - Confidence: 0.193
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/19.jpg - Class: scorpion - Confidence: 0.656
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/10.jpg - Class: centipede - Confidence: 0.557
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/3.jpg - Class: mask - Confidence: 0.432
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/21.jpg - Class: mask - Confidence: 0.305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/4.jpg - Class: tiger_shark - Confidence: 0.370
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/5.jpg - Class: baseball - Confidence: 0.453
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/22.jpg - Class: mask - Confidence: 0.227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/6.jpg - Class: mask - Confidence: 0.220
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/18.jpg - Class: scorpion - Confidence: 0.204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/12.jpg - Class: centipede - Confidence: 0.211
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/1.jpg - Class: plastic_bag - Confidence: 0.150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/11.jpg - Class: centipede - Confidence: 0.908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3844393089/17.jpg - Class: mask - Confidence: 0.355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/25.jpg - Class: fountain - Confidence: 0.146
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/14.jpg - Class: centipede - Confidence: 0.268
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/2.jpg - Class: radiator - Confidence: 0.212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/16.jpg - Class: centipede - Confidence: 0.597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/20.jpg - Class: radiator - Confidence: 0.118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/23.jpg - Class: tiger_shark - Confidence: 0.115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/24.jpg - Class: mask - Confidence: 0.115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/8.jpg - Class: radiator - Confidence: 0.251
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/15.jpg - Class: centipede - Confidence: 0.244
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/7.jpg - Class: mask - Confidence: 0.369
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/13.jpg - Class: trilobite - Confidence: 0.500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/9.jpg - Class: radiator - Confidence: 0.445
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/19.jpg - Class: scorpion - Confidence: 0.323
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/10.jpg - Class: centipede - Confidence: 0.357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/3.jpg - Class: radiator - Confidence: 0.306
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/21.jpg - Class: prison - Confidence: 0.292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/4.jpg - Class: tiger_shark - Confidence: 0.338
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/5.jpg - Class: combination_lock - Confidence: 0.210
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/22.jpg - Class: mask - Confidence: 0.126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/6.jpg - Class: radiator - Confidence: 0.208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/18.jpg - Class: scorpion - Confidence: 0.446
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/12.jpg - Class: centipede - Confidence: 0.135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/1.jpg - Class: plastic_bag - Confidence: 0.110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/11.jpg - Class: centipede - Confidence: 0.624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processed: /kaggle/working/converted_test_images/44036939/2828203845/17.jpg - Class: fountain - Confidence: 0.167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/25.jpg - Class: bubble - Confidence: 0.201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/14.jpg - Class: book_jacket - Confidence: 0.240
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/2.jpg - Class: binoculars - Confidence: 0.143
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/30.jpg - Class: television - Confidence: 0.220
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/40.jpg - Class: trilobite - Confidence: 0.636
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/16.jpg - Class: television - Confidence: 0.269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/33.jpg - Class: volcano - Confidence: 0.255
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/20.jpg - Class: book_jacket - Confidence: 0.094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/23.jpg - Class: television - Confidence: 0.433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/35.jpg - Class: book_jacket - Confidence: 0.075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/24.jpg - Class: book_jacket - Confidence: 0.150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/8.jpg - Class: television - Confidence: 0.060
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/42.jpg - Class: sunglasses - Confidence: 0.068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/43.jpg - Class: washbasin - Confidence: 0.092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/37.jpg - Class: custard_apple - Confidence: 0.362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/15.jpg - Class: television - Confidence: 0.310
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/7.jpg - Class: teddy - Confidence: 0.156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/13.jpg - Class: book_jacket - Confidence: 0.107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/9.jpg - Class: strainer - Confidence: 0.257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/19.jpg - Class: television - Confidence: 0.256
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/47.jpg - Class: fire_screen - Confidence: 0.226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/39.jpg - Class: binoculars - Confidence: 0.205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/34.jpg - Class: volcano - Confidence: 0.456
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/10.jpg - Class: frying_pan - Confidence: 0.292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/44.jpg - Class: chest - Confidence: 0.087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/3.jpg - Class: ladle - Confidence: 0.312
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/21.jpg - Class: television - Confidence: 0.148
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/26.jpg - Class: television - Confidence: 0.216
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/4.jpg - Class: binoculars - Confidence: 0.550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/28.jpg - Class: fire_screen - Confidence: 0.053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/41.jpg - Class: brass - Confidence: 0.075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/5.jpg - Class: oxygen_mask - Confidence: 0.287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/31.jpg - Class: television - Confidence: 0.211
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/38.jpg - Class: volcano - Confidence: 0.286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/22.jpg - Class: television - Confidence: 0.192
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/29.jpg - Class: teddy - Confidence: 0.135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/45.jpg - Class: mushroom - Confidence: 0.226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/27.jpg - Class: teddy - Confidence: 0.086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/6.jpg - Class: oxygen_mask - Confidence: 0.423
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/18.jpg - Class: television - Confidence: 0.185
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/12.jpg - Class: book_jacket - Confidence: 0.123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/1.jpg - Class: gasmask - Confidence: 0.066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/11.jpg - Class: gong - Confidence: 0.082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/36.jpg - Class: platypus - Confidence: 0.140
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/32.jpg - Class: television - Confidence: 0.404
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/46.jpg - Class: pizza - Confidence: 0.195
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processed: /kaggle/working/converted_test_images/44036939/3481971518/17.jpg - Class: book_jacket - Confidence: 0.234
# File: /kaggle/working/converted_test_images/44036939/3844393089/25.jpg, Class: fountain, Confidence: 0.646
# File: /kaggle/working/converted_test_images/44036939/3844393089/14.jpg, Class: trilobite, Confidence: 0.234
# File: /kaggle/working/converted_test_images/44036939/3844393089/2.jpg, Class: mask, Confidence: 0.164
# File: /kaggle/working/converted_test_images/44036939/3844393089/16.jpg, Class: tractor, Confidence: 0.141
# File: /kaggle/working/converted_test_images/44036939/3844393089/20.jpg, Class: prison, Confidence: 0.351
# File: /kaggle/working/converted_test_images/44036939/3844393089/23.jpg, Class: mask, Confidence: 0.305
# File: /kaggle/working/converted_test_images/44036939/3844393089/24.jpg, Class: mask, Confidence: 0.361
# File: /kaggle/working/converted_test_images/44036939/3844393089/8.jpg, Class: trilobite, Confidence: 0.384
# File: /kaggle/working/converted_test_images/44036939/3844393089/15.jpg, Class: centipede, Confidence: 0.304
# File: /kaggle/working/converted_test_images/44036939/3844393089/7.jpg, Class: mask, Confidence: 0.492
# File: /kaggle/working/converted_test_images/44036939/3844393089/13.jpg, Class: trilobite, Confidence: 0.466
# File: /kaggle/working/converted_test_images/44036939/3844393089/9.jpg, Class: nail, Confidence: 0.193
# File: /kaggle/working/converted_test_images/44036939/3844393089/19.jpg, Class: scorpion, Confidence: 0.656
# File: /kaggle/working/converted_test_images/44036939/3844393089/10.jpg, Class: centipede, Confidence: 0.557
# File: /kaggle/working/converted_test_images/44036939/3844393089/3.jpg, Class: mask, Confidence: 0.432
# File: /kaggle/working/converted_test_images/44036939/3844393089/21.jpg, Class: mask, Confidence: 0.305
# File: /kaggle/working/converted_test_images/44036939/3844393089/4.jpg, Class: tiger_shark, Confidence: 0.370
# File: /kaggle/working/converted_test_images/44036939/3844393089/5.jpg, Class: baseball, Confidence: 0.453
# File: /kaggle/working/converted_test_images/44036939/3844393089/22.jpg, Class: mask, Confidence: 0.227
# File: /kaggle/working/converted_test_images/44036939/3844393089/6.jpg, Class: mask, Confidence: 0.220
# File: /kaggle/working/converted_test_images/44036939/3844393089/18.jpg, Class: scorpion, Confidence: 0.204
# File: /kaggle/working/converted_test_images/44036939/3844393089/12.jpg, Class: centipede, Confidence: 0.211
# File: /kaggle/working/converted_test_images/44036939/3844393089/1.jpg, Class: plastic_bag, Confidence: 0.150
# File: /kaggle/working/converted_test_images/44036939/3844393089/11.jpg, Class: centipede, Confidence: 0.908
# File: /kaggle/working/converted_test_images/44036939/3844393089/17.jpg, Class: mask, Confidence: 0.355
# File: /kaggle/working/converted_test_images/44036939/2828203845/25.jpg, Class: fountain, Confidence: 0.146
# File: /kaggle/working/converted_test_images/44036939/2828203845/14.jpg, Class: centipede, Confidence: 0.268
# File: /kaggle/working/converted_test_images/44036939/2828203845/2.jpg, Class: radiator, Confidence: 0.212
# File: /kaggle/working/converted_test_images/44036939/2828203845/16.jpg, Class: centipede, Confidence: 0.597
# File: /kaggle/working/converted_test_images/44036939/2828203845/20.jpg, Class: radiator, Confidence: 0.118
# File: /kaggle/working/converted_test_images/44036939/2828203845/23.jpg, Class: tiger_shark, Confidence: 0.115
# File: /kaggle/working/converted_test_images/44036939/2828203845/24.jpg, Class: mask, Confidence: 0.115
# File: /kaggle/working/converted_test_images/44036939/2828203845/8.jpg, Class: radiator, Confidence: 0.251
# File: /kaggle/working/converted_test_images/44036939/2828203845/15.jpg, Class: centipede, Confidence: 0.244
# File: /kaggle/working/converted_test_images/44036939/2828203845/7.jpg, Class: mask, Confidence: 0.369
# File: /kaggle/working/converted_test_images/44036939/2828203845/13.jpg, Class: trilobite, Confidence: 0.500
# File: /kaggle/working/converted_test_images/44036939/2828203845/9.jpg, Class: radiator, Confidence: 0.445
# File: /kaggle/working/converted_test_images/44036939/2828203845/19.jpg, Class: scorpion, Confidence: 0.323
# File: /kaggle/working/converted_test_images/44036939/2828203845/10.jpg, Class: centipede, Confidence: 0.357
# File: /kaggle/working/converted_test_images/44036939/2828203845/3.jpg, Class: radiator, Confidence: 0.306
# File: /kaggle/working/converted_test_images/44036939/2828203845/21.jpg, Class: prison, Confidence: 0.292
# File: /kaggle/working/converted_test_images/44036939/2828203845/4.jpg, Class: tiger_shark, Confidence: 0.338
# File: /kaggle/working/converted_test_images/44036939/2828203845/5.jpg, Class: combination_lock, Confidence: 0.210
# File: /kaggle/working/converted_test_images/44036939/2828203845/22.jpg, Class: mask, Confidence: 0.126
# File: /kaggle/working/converted_test_images/44036939/2828203845/6.jpg, Class: radiator, Confidence: 0.208
# File: /kaggle/working/converted_test_images/44036939/2828203845/18.jpg, Class: scorpion, Confidence: 0.446
# File: /kaggle/working/converted_test_images/44036939/2828203845/12.jpg, Class: centipede, Confidence: 0.135
# File: /kaggle/working/converted_test_images/44036939/2828203845/1.jpg, Class: plastic_bag, Confidence: 0.110
# File: /kaggle/working/converted_test_images/44036939/2828203845/11.jpg, Class: centipede, Confidence: 0.624
# File: /kaggle/working/converted_test_images/44036939/2828203845/17.jpg, Class: fountain, Confidence: 0.167
# File: /kaggle/working/converted_test_images/44036939/3481971518/25.jpg, Class: bubble, Confidence: 0.201
# File: /kaggle/working/converted_test_images/44036939/3481971518/14.jpg, Class: book_jacket, Confidence: 0.240
# File: /kaggle/working/converted_test_images/44036939/3481971518/2.jpg, Class: binoculars, Confidence: 0.143
# File: /kaggle/working/converted_test_images/44036939/3481971518/30.jpg, Class: television, Confidence: 0.220
# File: /kaggle/working/converted_test_images/44036939/3481971518/40.jpg, Class: trilobite, Confidence: 0.636
# File: /kaggle/working/converted_test_images/44036939/3481971518/16.jpg, Class: television, Confidence: 0.269
# File: /kaggle/working/converted_test_images/44036939/3481971518/33.jpg, Class: volcano, Confidence: 0.255
# File: /kaggle/working/converted_test_images/44036939/3481971518/20.jpg, Class: book_jacket, Confidence: 0.094
# File: /kaggle/working/converted_test_images/44036939/3481971518/23.jpg, Class: television, Confidence: 0.433
# File: /kaggle/working/converted_test_images/44036939/3481971518/35.jpg, Class: book_jacket, Confidence: 0.075
# File: /kaggle/working/converted_test_images/44036939/3481971518/24.jpg, Class: book_jacket, Confidence: 0.150
# File: /kaggle/working/converted_test_images/44036939/3481971518/8.jpg, Class: television, Confidence: 0.060
# File: /kaggle/working/converted_test_images/44036939/3481971518/42.jpg, Class: sunglasses, Confidence: 0.068
# File: /kaggle/working/converted_test_images/44036939/3481971518/43.jpg, Class: washbasin, Confidence: 0.092
# File: /kaggle/working/converted_test_images/44036939/3481971518/37.jpg, Class: custard_apple, Confidence: 0.362
# File: /kaggle/working/converted_test_images/44036939/3481971518/15.jpg, Class: television, Confidence: 0.310
# File: /kaggle/working/converted_test_images/44036939/3481971518/7.jpg, Class: teddy, Confidence: 0.156
# File: /kaggle/working/converted_test_images/44036939/3481971518/13.jpg, Class: book_jacket, Confidence: 0.107
# File: /kaggle/working/converted_test_images/44036939/3481971518/9.jpg, Class: strainer, Confidence: 0.257
# File: /kaggle/working/converted_test_images/44036939/3481971518/19.jpg, Class: television, Confidence: 0.256
# File: /kaggle/working/converted_test_images/44036939/3481971518/47.jpg, Class: fire_screen, Confidence: 0.226
# File: /kaggle/working/converted_test_images/44036939/3481971518/39.jpg, Class: binoculars, Confidence: 0.205
# File: /kaggle/working/converted_test_images/44036939/3481971518/34.jpg, Class: volcano, Confidence: 0.456
# File: /kaggle/working/converted_test_images/44036939/3481971518/10.jpg, Class: frying_pan, Confidence: 0.292
# File: /kaggle/working/converted_test_images/44036939/3481971518/44.jpg, Class: chest, Confidence: 0.087
# File: /kaggle/working/converted_test_images/44036939/3481971518/3.jpg, Class: ladle, Confidence: 0.312
# File: /kaggle/working/converted_test_images/44036939/3481971518/21.jpg, Class: television, Confidence: 0.148
# File: /kaggle/working/converted_test_images/44036939/3481971518/26.jpg, Class: television, Confidence: 0.216
# File: /kaggle/working/converted_test_images/44036939/3481971518/4.jpg, Class: binoculars, Confidence: 0.550
# File: /kaggle/working/converted_test_images/44036939/3481971518/28.jpg, Class: fire_screen, Confidence: 0.053
# File: /kaggle/working/converted_test_images/44036939/3481971518/41.jpg, Class: brass, Confidence: 0.075
# File: /kaggle/working/converted_test_images/44036939/3481971518/5.jpg, Class: oxygen_mask, Confidence: 0.287
# File: /kaggle/working/converted_test_images/44036939/3481971518/31.jpg, Class: television, Confidence: 0.211
# File: /kaggle/working/converted_test_images/44036939/3481971518/38.jpg, Class: volcano, Confidence: 0.286
# File: /kaggle/working/converted_test_images/44036939/3481971518/22.jpg, Class: television, Confidence: 0.192
# File: /kaggle/working/converted_test_images/44036939/3481971518/29.jpg, Class: teddy, Confidence: 0.135
# File: /kaggle/working/converted_test_images/44036939/3481971518/45.jpg, Class: mushroom, Confidence: 0.226
# File: /kaggle/working/converted_test_images/44036939/3481971518/27.jpg, Class: teddy, Confidence: 0.086
# File: /kaggle/working/converted_test_images/44036939/3481971518/6.jpg, Class: oxygen_mask, Confidence: 0.423
# File: /kaggle/working/converted_test_images/44036939/3481971518/18.jpg, Class: television, Confidence: 0.185
# File: /kaggle/working/converted_test_images/44036939/3481971518/12.jpg, Class: book_jacket, Confidence: 0.123
# File: /kaggle/working/converted_test_images/44036939/3481971518/1.jpg, Class: gasmask, Confidence: 0.066
# File: /kaggle/working/converted_test_images/44036939/3481971518/11.jpg, Class: gong, Confidence: 0.082
# File: /kaggle/working/converted_test_images/44036939/3481971518/36.jpg, Class: platypus, Confidence: 0.140
# File: /kaggle/working/converted_test_images/44036939/3481971518/32.jpg, Class: television, Confidence: 0.404
# File: /kaggle/working/converted_test_images/44036939/3481971518/46.jpg, Class: pizza, Confidence: 0.195
# File: /kaggle/working/converted_test_images/44036939/3481971518/17.jpg, Class: book_jacket, Confidence: 0.234
# Results saved to image_test_rsna_2024_results.csv
