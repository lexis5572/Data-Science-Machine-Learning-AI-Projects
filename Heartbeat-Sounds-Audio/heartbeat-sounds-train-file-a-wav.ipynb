# %%
# %%time

import warnings
warnings.filterwarnings('ignore')
# Out:
# CPU times: user 25 µs, sys: 8 µs, total: 33 µs
# Wall time: 36.7 µs

# %%
# %%time

import wave

# Open the audio file
with wave.open('/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__101_1305030823364_A.wav', 'rb') as wf:
    sample_rate = wf.getframerate()  # Get sample rate calculation
    number_of_frames = wf.getnframes()  # Optional: Get number of frames
    print(f'Sample Rate: {sample_rate}')
# Out:
# Sample Rate: 44100
# CPU times: user 1.64 ms, sys: 3.19 ms, total: 4.83 ms
# Wall time: 20 ms

# %%
# %%time

import tensorflow as tf
import tensorflow_hub as hub

# Load the YAMNet model from TensorFlow Hub
yamnet_model = hub.load('https://www.kaggle.com/models/google/yamnet/TensorFlow2/yamnet/1')
# Out:
# CPU times: user 7.14 s, sys: 1.41 s, total: 8.54 s
# Wall time: 15.5 s

# %%
# %%time

import os 
import librosa 
import numpy as np 
import soundfile as sf 
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd 
import tensorflow as tf 
import tensorflow_hub as hub 
import io 
import csv 

# Function to extract class names from the model's class_map_path
def class_names_from_csv(class_map_csv_text):
    """Returns list of class names corresponding to score vector."""
    class_map_csv = io.StringIO(class_map_csv_text)
    # Skip the header
    csv_reader = csv.reader(class_map_csv)
    next(csv_reader)
    class_names = [display_name for (class_index, mid, display_name) in csv_reader]
    return class_names

# Load class names from the model's class_map_path
class_map_path = yamnet_model.class_map_path().numpy()
class_names = class_names_from_csv(tf.io.read_file(class_map_path).numpy().decode('utf-8'))

def preprocess_audio(audio_file_path, target_sr=44100):
    """ Preprocess audio file for YAMNet input.
    
    Parameters:
    -----------
    audio_file_path : str
        Path to audio file
    target_sr : int
        Target sampling rate (YAMNet expects 16kHz)

    Returns:
    --------
    numpy array : Preprocessed audio waveform
    """
    try:
        # Load and resample audio
        waveform, sr = librosa.load(audio_file_path, sr=target_sr)
        # Ensure minimum duration (1 second)
        if len(waveform) < target_sr:
            waveform = np.pad(waveform, (0, target_sr - len(waveform)))
        return waveform
    except Exception as e:
        print(f"Error processing {audio_file_path}: {str(e)}")
        return None

def classify_audio_file(audio_file_path):
    """ Classify audio file using YAMNet.
    
    Parameters:
    -----------
    audio_file_path : str
        Path to audio file

    Returns:
    --------
    tuple : (predicted_class, confidence_score)
    """
    try:
        # Preprocess audio
        waveform = preprocess_audio(audio_file_path, target_sr=44100)  # YAMNet expects kHz
        if waveform is None:
            return None, None
        # Run the model
        scores, embeddings, spectrogram = yamnet_model(waveform)
        # Get the predicted class and confidence
        class_scores = scores.numpy().mean(axis=0)
        predicted_class_idx = np.argmax(class_scores)
        confidence_score = class_scores[predicted_class_idx]
        # Get class name from the loaded class names
        predicted_class = class_names[predicted_class_idx]
        return predicted_class, confidence_score
    except Exception as e:
        print(f"Error classifying {audio_file_path}: {str(e)}")
        return None, None

def process_audio_directory(audio_directory, limit=1000):
    """ Process all audio files in a directory.
    
    Parameters:
    -----------
    audio_directory : str
        Path to directory containing audio files
    limit : int
        Maximum number of files to process

    Returns:
    --------
    list : List of (filename, prediction, confidence) tuples
    """
    results = []
    # Get list of audio files, now .wav format
    audio_files = [f for f in os.listdir(audio_directory) if f.lower().endswith('.wav')][:limit]
    # Process each file
    for audio_file in audio_files:
        audio_file_path = os.path.join(audio_directory, audio_file)
        predicted_class, confidence = classify_audio_file(audio_file_path)
        if predicted_class is not None:
            results.append((audio_file, predicted_class, confidence))
        print(f"Processed: {audio_file} - Class: {predicted_class} - Confidence: {confidence:.3f}")
    return results

def plot_results(results):
    """ Plot classification results.
    
    Parameters:
    -----------
    results : list
        List of (filename, prediction, confidence) tuples
    """
    if not results:
        print("No results to plot.")
        return
    
    # Extract predictions and confidences
    predictions = [r[1] for r in results]
    confidences = [r[2] for r in results]

    # Plot distribution of predictions
    plt.figure(figsize=(15, 5))
    
    # Prediction distribution
    plt.subplot(1, 2, 1)
    pred_counts = pd.Series(predictions).value_counts()
    sns.barplot(x=pred_counts.index, y=pred_counts.values)
    plt.xticks(rotation=90, ha='right')
    plt.title('Distribution of Predictions')
    
    # Confidence distribution
    plt.subplot(1, 2, 2)
    sns.histplot(confidences, bins=20)
    plt.title('Distribution of Confidence Scores')

    plt.tight_layout()
    plt.show()

# Main execution
if __name__ == "__main__":
    # Directory containing the audio files
    audio_directory = '/kaggle/input/heartbeat-sounds/set_a'
    # Process audio files
    print("Processing audio files...")
    results = process_audio_directory(audio_directory, limit=1000)

    # Create DataFrame
    if results:
        df_results = pd.DataFrame(results, columns=['filename', 'prediction', 'confidence'])
        # Print summary statistics
        print("\nSummary Statistics:")
        print("-" * 50)
        print(f"Total files processed: {len(df_results)}")
        print("\nPrediction counts:")
        print(df_results['prediction'].value_counts().head())
        print("\nConfidence score statistics:")
        print(df_results['confidence'].describe())
        # Plot results
        plot_results(results)
        
        # Save results confidence score is 0.1 or higher
        df_filtered = df_results[df_results['confidence'] >= 0.1]
        # Save the filtered DataFrame to a CSV file
        output_csv_path = 'trained_set_a_hearbeat_sound.csv'
        df_filtered.to_csv(output_csv_path, index=False)
        print(f"Filtered results saved to {output_csv_path}")
    else:
        print("No audio files processed successfully.")
# Out:
# Processing audio files...
# Processed: artifact__201106131834.wav - Class: Music - Confidence: 0.573
# Processed: Aunlabelledtest__201106061215.wav - Class: Silence - Confidence: 0.647
# Processed: artifact__201106101955.wav - Class: Explosion - Confidence: 0.215
# Processed: normal__201101151127.wav - Class: Static - Confidence: 0.147
# Processed: artifact__201106220340.wav - Class: Music - Confidence: 0.144
# Processed: artifact__201105190800.wav - Class: Silence - Confidence: 0.605
# Processed: normal__201102201230.wav - Class: Silence - Confidence: 0.983
# Processed: Aunlabelledtest__201108222241.wav - Class: Silence - Confidence: 0.772
# Processed: murmur__201102052338.wav - Class: Silence - Confidence: 0.197
# Processed: Aunlabelledtest__201106191034.wav - Class: Speech - Confidence: 0.153
# Processed: artifact__201106040722.wav - Class: Sidetone - Confidence: 0.498
# Processed: artifact__201106070949.wav - Class: Vehicle - Confidence: 0.290
# Processed: artifact__201106221254.wav - Class: Vehicle - Confidence: 0.233
# Processed: normal__201104122156.wav - Class: Heart sounds, heartbeat - Confidence: 0.275
# Processed: normal__201108011112.wav - Class: Silence - Confidence: 0.949
# Processed: extrahls__201102070251.wav - Class: Silence - Confidence: 0.992
# Processed: Aunlabelledtest__201103241336.wav - Class: Silence - Confidence: 0.784
# Processed: extrahls__201101152255.wav - Class: Silence - Confidence: 0.996
# Processed: artifact__201106010602.wav - Class: Vehicle - Confidence: 0.175
# Processed: Aunlabelledtest__201108222254.wav - Class: Silence - Confidence: 0.926
# Processed: murmur__201108222232.wav - Class: Silence - Confidence: 0.620
# Processed: Aunlabelledtest__201106061104.wav - Class: Skateboard - Confidence: 0.147
# Processed: normal__201102260502.wav - Class: Silence - Confidence: 0.931
# Processed: Aunlabelledtest__201103140236.wav - Class: Silence - Confidence: 0.966
# Processed: Aunlabelledtest__201106130440.wav - Class: Inside, small room - Confidence: 0.074
# Processed: murmur__201104241315.wav - Class: Wind - Confidence: 0.183
# Processed: extrahls__201104140118.wav - Class: Silence - Confidence: 0.976
# Processed: extrahls__201101160804.wav - Class: Silence - Confidence: 0.713
# Processed: artifact__201106021541.wav - Class: Silence - Confidence: 0.426
# Processed: normal__201106221418.wav - Class: Silence - Confidence: 0.493
# Processed: artifact__201106010559.wav - Class: Fire - Confidence: 0.147
# Processed: Aunlabelledtest__201104012144.wav - Class: Heart sounds, heartbeat - Confidence: 0.394
# Processed: artifact__201105061143.wav - Class: Silence - Confidence: 0.534
# Processed: Aunlabelledtest__201106150614.wav - Class: Whistling - Confidence: 0.541
# Processed: Aunlabelledtest__201106111419.wav - Class: Silence - Confidence: 0.823
# Processed: Aunlabelledtest__201108222257.wav - Class: Silence - Confidence: 0.928
# Processed: Aunlabelledtest__201012172010.wav - Class: Silence - Confidence: 0.911
# Processed: Aunlabelledtest__201108011116.wav - Class: Silence - Confidence: 0.946
# Processed: murmur__201101051114.wav - Class: Inside, small room - Confidence: 0.187
# Processed: Aunlabelledtest__201106031556.wav - Class: Silence - Confidence: 0.219
# Processed: normal__201105021804.wav - Class: Wind - Confidence: 0.170
# Processed: normal__201108011114.wav - Class: Silence - Confidence: 0.982
# Processed: murmur__201102051443.wav - Class: Outside, rural or natural - Confidence: 0.245
# Processed: artifact__201106110909.wav - Class: Silence - Confidence: 0.281
# Processed: normal__201106210943.wav - Class: Rustle - Confidence: 0.290
# Processed: murmur__201108222252.wav - Class: Silence - Confidence: 0.858
# Processed: normal__201103221214.wav - Class: Silence - Confidence: 1.000
# Processed: extrahls__201104021355.wav - Class: Silence - Confidence: 0.448
# Processed: normal__201103140822.wav - Class: Heart sounds, heartbeat - Confidence: 0.193
# Processed: artifact__201106161219.wav - Class: Silence - Confidence: 0.242
# Processed: normal__201104141251.wav - Class: Silence - Confidence: 0.873
# Processed: normal__201106151236.wav - Class: Silence - Confidence: 0.341
# Processed: artifact__201105040918.wav - Class: Silence - Confidence: 0.966
# Processed: Aunlabelledtest__201108222247.wav - Class: Silence - Confidence: 0.923
# Processed: extrahls__201103170134.wav - Class: Silence - Confidence: 0.522
# Processed: extrahls__201101241433.wav - Class: Heart sounds, heartbeat - Confidence: 0.652
# Processed: murmur__201104291843.wav - Class: Silence - Confidence: 0.677
# Processed: normal__201103140132.wav - Class: Silence - Confidence: 0.953
# Processed: extrahls__201101241423.wav - Class: Silence - Confidence: 0.618
# Processed: Aunlabelledtest__201108222222.wav - Class: Silence - Confidence: 0.798
# Processed: normal__201101070538.wav - Class: Silence - Confidence: 0.961
# Processed: extrahls__201101070953.wav - Class: Silence - Confidence: 1.000
# Processed: Aunlabelledtest__201101110659.wav - Class: Heart sounds, heartbeat - Confidence: 0.347
# Processed: Aunlabelledtest__201103201314.wav - Class: Silence - Confidence: 0.762
# Processed: Aunlabelledtest__20110501548.wav - Class: Wind - Confidence: 0.226
# Processed: artifact__201106211041.wav - Class: Silence - Confidence: 0.804
# Processed: Aunlabelledtest__201102081033.wav - Class: Silence - Confidence: 0.441
# Processed: artifact__201106211430.wav - Class: Silence - Confidence: 0.260
# Processed: murmur__201108222253.wav - Class: Silence - Confidence: 0.836
# Processed: Aunlabelledtest__201101241434.wav - Class: Heart sounds, heartbeat - Confidence: 0.600
# Processed: normal__201106221450.wav - Class: Silence - Confidence: 0.737
# Processed: normal__201105151450.wav - Class: Silence - Confidence: 0.899
# Processed: Aunlabelledtest__201108011111.wav - Class: Silence - Confidence: 0.969
# Processed: normal__201103140135.wav - Class: Silence - Confidence: 0.867
# Processed: murmur__201108222226.wav - Class: Silence - Confidence: 0.880
# Processed: murmur__201108222224.wav - Class: Silence - Confidence: 0.888
# Processed: artifact__201105280851.wav - Class: Boat, Water vehicle - Confidence: 0.267
# Processed: Aunlabelledtest__201103200518.wav - Class: Silence - Confidence: 1.000
# Processed: Aunlabelledtest__201106170857.wav - Class: Silence - Confidence: 0.255
# Processed: murmur__201108222242.wav - Class: Silence - Confidence: 0.725
# Processed: artifact__201105051017.wav - Class: Fire - Confidence: 0.107
# Processed: murmur__201108222233.wav - Class: Silence - Confidence: 0.492
# Processed: Aunlabelledtest__201106212102.wav - Class: Silence - Confidence: 0.321
# Processed: normal__201102081152.wav - Class: Beep, bleep - Confidence: 0.174
# Processed: artifact__201106131835.wav - Class: Music - Confidence: 0.648
# Processed: Aunlabelledtest__201108222228.wav - Class: Silence - Confidence: 0.883
# Processed: Aunlabelledtest__201106211725.wav - Class: Silence - Confidence: 0.869
# Processed: murmur__201108222248.wav - Class: Silence - Confidence: 0.889
# Processed: extrahls__201101161027.wav - Class: Silence - Confidence: 0.277
# Processed: artifact__201106050353.wav - Class: Silence - Confidence: 0.188
# Processed: artifact__201106141701.wav - Class: Silence - Confidence: 0.602
# Processed: artifact__201106031558.wav - Class: Silence - Confidence: 0.273
# Processed: extrahls__201101091153.wav - Class: Silence - Confidence: 0.635
# Processed: Aunlabelledtest__201106030607.wav - Class: Heart sounds, heartbeat - Confidence: 0.112
# Processed: Aunlabelledtest__201108222234.wav - Class: Silence - Confidence: 0.902
# Processed: murmur__201101051104.wav - Class: Silence - Confidence: 0.856
# Processed: normal__201105021654.wav - Class: Silence - Confidence: 0.159
# Processed: artifact__201106161016.wav - Class: Silence - Confidence: 0.758
# Processed: normal__201103170121.wav - Class: Silence - Confidence: 0.522
# Processed: Aunlabelledtest__201102081045.wav - Class: Silence - Confidence: 1.000
# Processed: murmur__201108222256.wav - Class: Silence - Confidence: 0.951
# Processed: artifact__201106101314.wav - Class: Vehicle - Confidence: 0.371
# Processed: normal__201103101140.wav - Class: Silence - Confidence: 0.965
# Processed: Aunlabelledtest__201106040930.wav - Class: Silence - Confidence: 0.274
# Processed: murmur__201108222227.wav - Class: Silence - Confidence: 0.909
# Processed: Aunlabelledtest__201106100606.wav - Class: Silence - Confidence: 0.563
# Processed: murmur__201108222258.wav - Class: Silence - Confidence: 0.938
# Processed: murmur__201101051108.wav - Class: Silence - Confidence: 0.913
# Processed: murmur__201106141148.wav - Class: Heart sounds, heartbeat - Confidence: 0.309
# Processed: normal__201106111136.wav - Class: Heart sounds, heartbeat - Confidence: 0.163
# Processed: normal__201102081321.wav - Class: Mechanical fan - Confidence: 0.312
# Processed: artifact__201106161019.wav - Class: Throbbing - Confidence: 0.146
# Processed: murmur__201108222243.wav - Class: Silence - Confidence: 0.503
# Processed: Aunlabelledtest__201101220549.wav - Class: Silence - Confidence: 0.212
# Processed: murmur__201108222245.wav - Class: Silence - Confidence: 0.978
# Processed: normal__201103151912.wav - Class: Silence - Confidence: 0.548
# Processed: artifact__201106040933.wav - Class: Silence - Confidence: 0.201
# Processed: murmur__201108222255.wav - Class: Silence - Confidence: 0.917
# Processed: artifact__201106111119.wav - Class: Alarm - Confidence: 0.259
# Processed: normal__201105011626.wav - Class: Mechanical fan - Confidence: 0.199
# Processed: normal__201108011118.wav - Class: Silence - Confidence: 0.932
# Processed: artifact__201106121242.wav - Class: Vehicle - Confidence: 0.255
# Processed: normal__201108011115.wav - Class: Silence - Confidence: 0.970
# Processed: artifact__201012172012.wav - Class: Silence - Confidence: 0.853
# Processed: artifact__201106190520.wav - Class: Silence - Confidence: 0.792
# Processed: murmur__201101180902.wav - Class: Silence - Confidence: 0.787
# Processed: extrahls__201101160808.wav - Class: Silence - Confidence: 0.532
# Processed: murmur__201108222236.wav - Class: Silence - Confidence: 0.906
# Processed: extrahls__201103182227.wav - Class: Silence - Confidence: 0.999
# Processed: Aunlabelledtest__201106120928.wav - Class: Silence - Confidence: 1.000
# Processed: Aunlabelledtest__201103232251.wav - Class: Silence - Confidence: 0.427
# Processed: Aunlabelledtest__201108222225.wav - Class: Silence - Confidence: 0.901
# Processed: Aunlabelledtest__2011040239.wav - Class: Silence - Confidence: 0.188
# Processed: artifact__201106070537.wav - Class: Music - Confidence: 0.233
# Processed: Aunlabelledtest__201102200848.wav - Class: Silence - Confidence: 1.000
# Processed: Aunlabelledtest__201108011113.wav - Class: Silence - Confidence: 0.945
# Processed: Aunlabelledtest__201101051105.wav - Class: Silence - Confidence: 0.837
# Processed: Aunlabelledtest__201105011546.wav - Class: Wind - Confidence: 0.233
# Processed: murmur__201108222251.wav - Class: Silence - Confidence: 0.891
# Processed: artifact__201106040947.wav - Class: Silence - Confidence: 0.306
# Processed: extrahls__201103150114.wav - Class: Heart sounds, heartbeat - Confidence: 0.342
# Processed: Aunlabelledtest__201101061552.wav - Class: Silence - Confidence: 0.470
# Processed: Aunlabelledtest__201106171155.wav - Class: Rumble - Confidence: 0.113
# Processed: murmur__201108222235.wav - Class: Silence - Confidence: 0.876
# Processed: murmur__201108222231.wav - Class: Silence - Confidence: 0.769
# Processed: Aunlabelledtest__201101152256.wav - Class: Silence - Confidence: 0.973
# Processed: extrahls__201102071835.wav - Class: Silence - Confidence: 1.000
# Processed: artifact__201106041452.wav - Class: Vehicle - Confidence: 0.441
# Processed: murmur__201103291548.wav - Class: Silence - Confidence: 0.990
# Processed: extrahls__201104270459.wav - Class: Heart sounds, heartbeat - Confidence: 0.594
# Processed: artifact__201106212112.wav - Class: Vehicle - Confidence: 0.293
# Processed: murmur__201108222221.wav - Class: Silence - Confidence: 0.842
# Processed: murmur__201108222237.wav - Class: Silence - Confidence: 0.897
# Processed: Aunlabelledtest__201108222244.wav - Class: Silence - Confidence: 0.422
# Processed: artifact__201106171003.wav - Class: Inside, small room - Confidence: 0.098
# Processed: Aunlabelledtest__201103170122.wav - Class: Silence - Confidence: 0.531
# Processed: artifact__201106121445.wav - Class: Silence - Confidence: 0.999
# Processed: extrahls__201103200218.wav - Class: Heart sounds, heartbeat - Confidence: 0.268
# Processed: extrahls__201104270458.wav - Class: Heart sounds, heartbeat - Confidence: 0.365
# Processed: normal__201102270940.wav - Class: Silence - Confidence: 0.910
# Processed: artifact__201105060108.wav - Class: Outside, rural or natural - Confidence: 0.081
# Processed: normal__201103090635.wav - Class: Silence - Confidence: 0.996
# Processed: murmur__201108222223.wav - Class: Silence - Confidence: 0.725
# Processed: extrahls__201102241217.wav - Class: Silence - Confidence: 0.949
# Processed: artifact__201106030612.wav - Class: Silence - Confidence: 0.574
# Processed: Aunlabelledtest__201106010807.wav - Class: Silence - Confidence: 0.439
# Processed: normal__201106141148.wav - Class: Heart sounds, heartbeat - Confidence: 0.316
# Processed: artifact__201106061233.wav - Class: Silence - Confidence: 0.217
# Processed: Aunlabelledtest__201108011117.wav - Class: Silence - Confidence: 0.948
# Processed: Aunlabelledtest__201101091156.wav - Class: Silence - Confidence: 0.529
# Processed: murmur__201104021355.wav - Class: Silence - Confidence: 0.451
# Processed: murmur__201108222238.wav - Class: Silence - Confidence: 0.878
# Processed: Aunlabelledtest__201103011036.wav - Class: Silence - Confidence: 0.754
# Processed: murmur__201108222246.wav - Class: Silence - Confidence: 0.911
# Processed: artifact__201105041959.wav - Class: Silence - Confidence: 0.801
# Processed: Aunlabelledtest__201105031730.wav - Class: Heart sounds, heartbeat - Confidence: 0.192
#
# Summary Statistics:
# --------------------------------------------------
# Total files processed: 176
#
# Prediction counts:
# prediction
# Silence                    125
# Heart sounds, heartbeat     15
# Vehicle                      7
# Music                        4
# Wind                         4
# Name: count, dtype: int64
#
# Confidence score statistics:
# count    176.000000
# mean       0.594933
# std        0.310653
# min        0.074159
# 25%        0.274602
# 50%        0.603453
# 75%        0.903370
# max        1.000000
# Name: confidence, dtype: float64
# Filtered results saved to trained_set_a_hearbeat_sound.csv
# CPU times: user 18 s, sys: 1.21 s, total: 19.2 s
# Wall time: 24.7 s
