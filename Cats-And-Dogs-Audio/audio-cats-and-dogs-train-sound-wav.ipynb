# %% [markdown]
# - File sources : https://www.kaggle.com/datasets/mmoreaux/audio-cats-and-dogs/data

# %%
# %%time

import warnings
warnings.filterwarnings('ignore')
# Out:
# CPU times: user 26 µs, sys: 10 µs, total: 36 µs
# Wall time: 38.4 µs

# %%
# %%time

import wave

# Open the audio file
with wave.open('/kaggle/input/audio-cats-and-dogs/cats_dogs/test/cats/cat_110.wav', 'rb') as wf:
    sample_rate = wf.getframerate()  # Get sample rate calculation
    number_of_frames = wf.getnframes()  # Optional: Get number of frames
    print(f'Sample Rate: {sample_rate}')
# Out:
# Sample Rate: 16000
# CPU times: user 2.49 ms, sys: 562 µs, total: 3.05 ms
# Wall time: 41 ms

# %%
# %%time

import tensorflow as tf
import tensorflow_hub as hub

# Load the YAMNet model from TensorFlow Hub
yamnet_model = hub.load('https://www.kaggle.com/models/google/yamnet/TensorFlow2/yamnet/1')
# Out:
# CPU times: user 6.86 s, sys: 1.35 s, total: 8.22 s
# Wall time: 13.6 s

# %%
# %%time

import os 
import librosa 
import numpy as np 
import soundfile as sf 
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd 
import tensorflow as tf 
import tensorflow_hub as hub 
import io 
import csv 

# Function to extract class names from the model's class_map_path
def class_names_from_csv(class_map_csv_text):
    """Returns list of class names corresponding to score vector."""
    class_map_csv = io.StringIO(class_map_csv_text)
    # Skip the header
    csv_reader = csv.reader(class_map_csv)
    next(csv_reader)
    class_names = [display_name for (class_index, mid, display_name) in csv_reader]
    return class_names

# Load class names from the model's class_map_path
class_map_path = yamnet_model.class_map_path().numpy()
class_names = class_names_from_csv(tf.io.read_file(class_map_path).numpy().decode('utf-8'))

def preprocess_audio(audio_file_path, target_sr=16000):
    """ Preprocess audio file for YAMNet input.
    
    Parameters:
    -----------
    audio_file_path : str
        Path to audio file
    target_sr : int
        Target sampling rate (YAMNet expects 16kHz)

    Returns:
    --------
    numpy array : Preprocessed audio waveform
    """
    try:
        # Load and resample audio
        waveform, sr = librosa.load(audio_file_path, sr=target_sr)
        # Ensure minimum duration (1 second)
        if len(waveform) < target_sr:
            waveform = np.pad(waveform, (0, target_sr - len(waveform)))
        return waveform
    except Exception as e:
        print(f"Error processing {audio_file_path}: {str(e)}")
        return None

def classify_audio_file(audio_file_path):
    """ Classify audio file using YAMNet.
    
    Parameters:
    -----------
    audio_file_path : str
        Path to audio file

    Returns:
    --------
    tuple : (predicted_class, confidence_score)
    """
    try:
        # Preprocess audio
        waveform = preprocess_audio(audio_file_path, target_sr=16000)  # YAMNet expects kHz
        if waveform is None:
            return None, None
        # Run the model
        scores, embeddings, spectrogram = yamnet_model(waveform)
        # Get the predicted class and confidence
        class_scores = scores.numpy().mean(axis=0)
        predicted_class_idx = np.argmax(class_scores)
        confidence_score = class_scores[predicted_class_idx]
        # Get class name from the loaded class names
        predicted_class = class_names[predicted_class_idx]
        return predicted_class, confidence_score
    except Exception as e:
        print(f"Error classifying {audio_file_path}: {str(e)}")
        return None, None

def process_audio_directory(audio_directory, limit=500):
    """ Process all audio files in a directory.
    
    Parameters:
    -----------
    audio_directory : str
        Path to directory containing audio files
    limit : int
        Maximum number of files to process

    Returns:
    --------
    list : List of (filename, prediction, confidence) tuples
    """
    results = []
    # Get list of audio files, now .wav format
    audio_files = [f for f in os.listdir(audio_directory) if f.lower().endswith('.wav')][:limit]
    # Process each file
    for audio_file in audio_files:
        audio_file_path = os.path.join(audio_directory, audio_file)
        predicted_class, confidence = classify_audio_file(audio_file_path)
        if predicted_class is not None:
            results.append((audio_file, predicted_class, confidence))
        print(f"Processed: {audio_file} - Class: {predicted_class} - Confidence: {confidence:.3f}")
    return results

def plot_results(results):
    """ Plot classification results.
    
    Parameters:
    -----------
    results : list
        List of (filename, prediction, confidence) tuples
    """
    if not results:
        print("No results to plot.")
        return
    
    # Extract predictions and confidences
    predictions = [r[1] for r in results]
    confidences = [r[2] for r in results]

    # Plot distribution of predictions
    plt.figure(figsize=(15, 5))
    
    # Prediction distribution
    plt.subplot(1, 2, 1)
    pred_counts = pd.Series(predictions).value_counts()
    sns.barplot(x=pred_counts.index, y=pred_counts.values)
    plt.xticks(rotation=90, ha='right')
    plt.title('Distribution of Predictions')
    
    # Confidence distribution
    plt.subplot(1, 2, 2)
    sns.histplot(confidences, bins=20)
    plt.title('Distribution of Confidence Scores')

    plt.tight_layout()
    plt.show()

# Main execution
if __name__ == "__main__":
    # Directory containing the audio files
    audio_directory = '/kaggle/input/audio-cats-and-dogs/cats_dogs'
    # Process audio files
    print("Processing audio files...")
    results = process_audio_directory(audio_directory, limit=500)

    # Create DataFrame
    if results:
        df_results = pd.DataFrame(results, columns=['filename', 'prediction', 'confidence'])
        # Print summary statistics
        print("\nSummary Statistics:")
        print("-" * 50)
        print(f"Total files processed: {len(df_results)}")
        print("\nPrediction counts:")
        print(df_results['prediction'].value_counts().head())
        print("\nConfidence score statistics:")
        print(df_results['confidence'].describe())
        # Plot results
        plot_results(results)
        
        # Save results confidence score is 0.1 or higher
        df_filtered = df_results[df_results['confidence'] >= 0.1]
        # Save the filtered DataFrame to a CSV file
        output_csv_path = 'test_cat_dog_sounds.csv'
        df_filtered.to_csv(output_csv_path, index=False)
        print(f"Filtered results saved to {output_csv_path}")
    else:
        print("No audio files processed successfully.")
# Out:
# Processing audio files...
# Processed: dog_barking_102.wav - Class: Animal - Confidence: 0.418
# Processed: cat_43.wav - Class: Animal - Confidence: 0.327
# Processed: dog_barking_29.wav - Class: Chant - Confidence: 0.485
# Processed: cat_47.wav - Class: Animal - Confidence: 0.694
# Processed: dog_barking_50.wav - Class: Dog - Confidence: 0.593
# Processed: dog_barking_83.wav - Class: Dog - Confidence: 0.458
# Processed: cat_83.wav - Class: Crying, sobbing - Confidence: 0.362
# Processed: cat_84.wav - Class: Animal - Confidence: 0.508
# Processed: cat_129.wav - Class: Speech - Confidence: 0.433
# Processed: cat_74.wav - Class: Animal - Confidence: 0.634
# Processed: cat_124.wav - Class: Animal - Confidence: 0.998
# Processed: dog_barking_30.wav - Class: Domestic animals, pets - Confidence: 0.582
# Processed: cat_89.wav - Class: Animal - Confidence: 0.927
# Processed: cat_52.wav - Class: Domestic animals, pets - Confidence: 0.684
# Processed: dog_barking_98.wav - Class: Dog - Confidence: 0.372
# Processed: cat_21.wav - Class: Animal - Confidence: 0.355
# Processed: cat_103.wav - Class: Animal - Confidence: 0.130
# Processed: cat_153.wav - Class: Animal - Confidence: 0.544
# Processed: cat_165.wav - Class: Speech - Confidence: 0.309
# Processed: cat_70.wav - Class: Animal - Confidence: 0.327
# Processed: dog_barking_33.wav - Class: Animal - Confidence: 0.323
# Processed: dog_barking_32.wav - Class: Animal - Confidence: 0.445
# Processed: cat_100.wav - Class: Animal - Confidence: 0.471
# Processed: dog_barking_2.wav - Class: Animal - Confidence: 0.863
# Processed: dog_barking_17.wav - Class: Animal - Confidence: 0.996
# Processed: cat_13.wav - Class: Speech - Confidence: 0.212
# Processed: cat_63.wav - Class: Animal - Confidence: 0.400
# Processed: cat_11.wav - Class: Speech - Confidence: 0.109
# Processed: cat_109.wav - Class: Speech - Confidence: 0.280
# Processed: dog_barking_6.wav - Class: Domestic animals, pets - Confidence: 0.832
# Processed: dog_barking_88.wav - Class: Animal - Confidence: 0.938
# Processed: cat_130.wav - Class: Animal - Confidence: 0.600
# Processed: cat_136.wav - Class: Cat - Confidence: 0.339
# Processed: cat_150.wav - Class: Animal - Confidence: 0.672
# Processed: dog_barking_101.wav - Class: Animal - Confidence: 0.785
# Processed: cat_139.wav - Class: Crying, sobbing - Confidence: 0.237
# Processed: dog_barking_15.wav - Class: Animal - Confidence: 0.950
# Processed: cat_69.wav - Class: Silence - Confidence: 0.361
# Processed: dog_barking_94.wav - Class: Animal - Confidence: 0.828
# Processed: cat_72.wav - Class: Animal - Confidence: 0.800
# Processed: cat_156.wav - Class: Crying, sobbing - Confidence: 0.452
# Processed: dog_barking_13.wav - Class: Animal - Confidence: 0.984
# Processed: cat_28.wav - Class: Animal - Confidence: 0.300
# Processed: cat_120.wav - Class: Animal - Confidence: 0.481
# Processed: dog_barking_60.wav - Class: Animal - Confidence: 0.915
# Processed: cat_19.wav - Class: Animal - Confidence: 0.578
# Processed: cat_128.wav - Class: Crying, sobbing - Confidence: 0.188
# Processed: dog_barking_85.wav - Class: Chant - Confidence: 0.257
# Processed: dog_barking_27.wav - Class: Animal - Confidence: 0.994
# Processed: cat_141.wav - Class: Animal - Confidence: 0.884
# Processed: cat_67.wav - Class: Cat - Confidence: 0.987
# Processed: cat_68.wav - Class: Cat - Confidence: 0.259
# Processed: cat_93.wav - Class: Domestic animals, pets - Confidence: 0.616
# Processed: dog_barking_42.wav - Class: Dog - Confidence: 0.297
# Processed: cat_86.wav - Class: Animal - Confidence: 0.387
# Processed: cat_142.wav - Class: Animal - Confidence: 0.541
# Processed: cat_10.wav - Class: Crying, sobbing - Confidence: 0.373
# Processed: dog_barking_9.wav - Class: Animal - Confidence: 0.987
# Processed: dog_barking_1.wav - Class: Animal - Confidence: 0.846
# Processed: dog_barking_93.wav - Class: Animal - Confidence: 0.637
# Processed: dog_barking_66.wav - Class: Animal - Confidence: 0.788
# Processed: dog_barking_52.wav - Class: Dog - Confidence: 0.220
# Processed: dog_barking_34.wav - Class: Animal - Confidence: 0.718
# Processed: cat_36.wav - Class: Animal - Confidence: 0.294
# Processed: cat_91.wav - Class: Wail, moan - Confidence: 0.299
# Processed: cat_45.wav - Class: Speech - Confidence: 0.316
# Processed: dog_barking_72.wav - Class: Animal - Confidence: 0.853
# Processed: cat_38.wav - Class: Animal - Confidence: 0.149
# Processed: cat_88.wav - Class: Domestic animals, pets - Confidence: 0.798
# Processed: cat_119.wav - Class: Cat - Confidence: 0.128
# Processed: cat_167.wav - Class: Speech - Confidence: 0.334
# Processed: cat_76.wav - Class: Domestic animals, pets - Confidence: 0.538
# Processed: cat_42.wav - Class: Animal - Confidence: 0.392
# Processed: cat_116.wav - Class: Cat - Confidence: 0.179
# Processed: cat_20.wav - Class: Animal - Confidence: 0.712
# Processed: cat_56.wav - Class: Screaming - Confidence: 0.689
# Processed: cat_158.wav - Class: Animal - Confidence: 0.323
# Processed: cat_96.wav - Class: Animal - Confidence: 0.153
# Processed: dog_barking_18.wav - Class: Animal - Confidence: 0.300
# Processed: dog_barking_45.wav - Class: Chant - Confidence: 0.442
# Processed: dog_barking_7.wav - Class: Animal - Confidence: 0.490
# Processed: cat_106.wav - Class: Animal - Confidence: 0.283
# Processed: dog_barking_56.wav - Class: Dog - Confidence: 0.723
# Processed: dog_barking_25.wav - Class: Music - Confidence: 0.619
# Processed: cat_157.wav - Class: Animal - Confidence: 0.304
# Processed: cat_6.wav - Class: Cat - Confidence: 0.916
# Processed: cat_73.wav - Class: Animal - Confidence: 0.754
# Processed: cat_4.wav - Class: Cat - Confidence: 0.860
# Processed: cat_160.wav - Class: Animal - Confidence: 0.213
# Processed: cat_25.wav - Class: Animal - Confidence: 0.306
# Processed: dog_barking_4.wav - Class: Animal - Confidence: 0.935
# Processed: dog_barking_12.wav - Class: Animal - Confidence: 0.650
# Processed: dog_barking_92.wav - Class: Domestic animals, pets - Confidence: 0.856
# Processed: cat_17.wav - Class: Alarm - Confidence: 0.497
# Processed: dog_barking_46.wav - Class: Chant - Confidence: 0.375
# Processed: dog_barking_89.wav - Class: Dog - Confidence: 0.637
# Processed: cat_159.wav - Class: Inside, small room - Confidence: 0.163
# Processed: dog_barking_70.wav - Class: Whimper - Confidence: 0.252
# Processed: cat_3.wav - Class: Inside, small room - Confidence: 0.229
# Processed: cat_162.wav - Class: Animal - Confidence: 0.546
# Processed: cat_26.wav - Class: Animal - Confidence: 0.289
# Processed: cat_61.wav - Class: Domestic animals, pets - Confidence: 0.258
# Processed: cat_54.wav - Class: Screaming - Confidence: 0.364
# Processed: dog_barking_59.wav - Class: Dog - Confidence: 0.311
# Processed: cat_24.wav - Class: Vehicle - Confidence: 0.393
# Processed: cat_51.wav - Class: Water - Confidence: 0.130
# Processed: cat_98.wav - Class: Speech - Confidence: 0.299
# Processed: dog_barking_3.wav - Class: Dog - Confidence: 0.512
# Processed: dog_barking_28.wav - Class: Animal - Confidence: 0.858
# Processed: cat_127.wav - Class: Animal - Confidence: 0.203
# Processed: cat_87.wav - Class: Animal - Confidence: 0.539
# Processed: cat_22.wav - Class: Animal - Confidence: 0.614
# Processed: dog_barking_21.wav - Class: Domestic animals, pets - Confidence: 0.248
# Processed: dog_barking_10.wav - Class: Animal - Confidence: 0.991
# Processed: cat_125.wav - Class: Animal - Confidence: 0.657
# Processed: dog_barking_100.wav - Class: Cat - Confidence: 0.227
# Processed: cat_149.wav - Class: Animal - Confidence: 0.465
# Processed: cat_107.wav - Class: Animal - Confidence: 0.494
# Processed: dog_barking_63.wav - Class: Animal - Confidence: 0.581
# Processed: dog_barking_58.wav - Class: Animal - Confidence: 0.409
# Processed: dog_barking_78.wav - Class: Howl - Confidence: 0.308
# Processed: cat_7.wav - Class: Domestic animals, pets - Confidence: 0.937
# Processed: cat_41.wav - Class: Skateboard - Confidence: 0.184
# Processed: cat_131.wav - Class: Animal - Confidence: 0.365
# Processed: dog_barking_41.wav - Class: Animal - Confidence: 0.309
# Processed: dog_barking_53.wav - Class: Chant - Confidence: 0.238
# Processed: dog_barking_106.wav - Class: Animal - Confidence: 0.843
# Processed: dog_barking_82.wav - Class: Domestic animals, pets - Confidence: 0.532
# Processed: cat_58.wav - Class: Cat - Confidence: 0.608
# Processed: cat_5.wav - Class: Animal - Confidence: 0.755
# Processed: cat_123.wav - Class: Music - Confidence: 0.870
# Processed: cat_99.wav - Class: Speech - Confidence: 0.143
# Processed: dog_barking_16.wav - Class: Domestic animals, pets - Confidence: 0.669
# Processed: dog_barking_84.wav - Class: Animal - Confidence: 0.895
# Processed: dog_barking_97.wav - Class: Animal - Confidence: 0.904
# Processed: dog_barking_47.wav - Class: Chant - Confidence: 0.285
# Processed: cat_163.wav - Class: Animal - Confidence: 0.633
# Processed: cat_23.wav - Class: Animal - Confidence: 0.486
# Processed: dog_barking_48.wav - Class: Animal - Confidence: 0.531
# Processed: dog_barking_71.wav - Class: Chant - Confidence: 0.330
# Processed: cat_34.wav - Class: Animal - Confidence: 0.487
# Processed: cat_64.wav - Class: Animal - Confidence: 0.679
# Processed: cat_144.wav - Class: Silence - Confidence: 0.103
# Processed: cat_151.wav - Class: Speech - Confidence: 0.276
# Processed: cat_140.wav - Class: Crying, sobbing - Confidence: 0.374
# Processed: cat_66.wav - Class: Crying, sobbing - Confidence: 0.461
# Processed: dog_barking_79.wav - Class: Animal - Confidence: 0.548
# Processed: dog_barking_26.wav - Class: Domestic animals, pets - Confidence: 0.862
# Processed: cat_53.wav - Class: Speech - Confidence: 0.122
# Processed: cat_134.wav - Class: Cat - Confidence: 0.482
# Processed: cat_143.wav - Class: Animal - Confidence: 0.573
# Processed: cat_35.wav - Class: Animal - Confidence: 0.372
# Processed: cat_49.wav - Class: Animal - Confidence: 0.361
# Processed: dog_barking_91.wav - Class: Dog - Confidence: 0.843
# Processed: cat_37.wav - Class: Cat - Confidence: 0.344
# Processed: dog_barking_90.wav - Class: Dog - Confidence: 0.784
# Processed: cat_1.wav - Class: Inside, small room - Confidence: 0.313
# Processed: cat_33.wav - Class: Animal - Confidence: 0.479
# Processed: dog_barking_81.wav - Class: Animal - Confidence: 0.641
# Processed: dog_barking_110.wav - Class: Dog - Confidence: 0.600
# Processed: cat_152.wav - Class: Animal - Confidence: 0.623
# Processed: cat_133.wav - Class: Domestic animals, pets - Confidence: 0.171
# Processed: cat_94.wav - Class: Animal - Confidence: 0.378
# Processed: cat_148.wav - Class: Animal - Confidence: 0.346
# Processed: cat_44.wav - Class: Animal - Confidence: 0.121
# Processed: cat_78.wav - Class: Crying, sobbing - Confidence: 0.242
# Processed: cat_135.wav - Class: Speech - Confidence: 0.398
# Processed: cat_77.wav - Class: Animal - Confidence: 0.215
# Processed: dog_barking_73.wav - Class: Animal - Confidence: 0.994
# Processed: dog_barking_80.wav - Class: Dog - Confidence: 0.749
# Processed: cat_75.wav - Class: Cat - Confidence: 0.141
# Processed: dog_barking_36.wav - Class: Yodeling - Confidence: 0.216
# Processed: dog_barking_5.wav - Class: Animal - Confidence: 0.966
# Processed: dog_barking_103.wav - Class: Dog - Confidence: 0.693
# Processed: dog_barking_14.wav - Class: Animal - Confidence: 0.950
# Processed: cat_126.wav - Class: Animal - Confidence: 0.268
# Processed: cat_166.wav - Class: Speech - Confidence: 0.309
# Processed: dog_barking_74.wav - Class: Animal - Confidence: 0.672
# Processed: cat_118.wav - Class: Animal - Confidence: 0.173
# Processed: cat_57.wav - Class: Cat - Confidence: 0.442
# Processed: dog_barking_55.wav - Class: Dog - Confidence: 0.558
# Processed: cat_137.wav - Class: Crying, sobbing - Confidence: 0.286
# Processed: dog_barking_62.wav - Class: Animal - Confidence: 0.615
# Processed: cat_48.wav - Class: Animal - Confidence: 0.687
# Processed: cat_113.wav - Class: Speech - Confidence: 0.252
# Processed: cat_29.wav - Class: Animal - Confidence: 0.354
# Processed: cat_9.wav - Class: Speech - Confidence: 0.167
# Processed: dog_barking_24.wav - Class: Animal - Confidence: 0.846
# Processed: dog_barking_109.wav - Class: Hum - Confidence: 0.150
# Processed: cat_31.wav - Class: Animal - Confidence: 0.686
# Processed: cat_132.wav - Class: Animal - Confidence: 0.163
# Processed: cat_108.wav - Class: Animal - Confidence: 0.582
# Processed: cat_15.wav - Class: Cat - Confidence: 0.500
# Processed: cat_27.wav - Class: Domestic animals, pets - Confidence: 0.415
# Processed: dog_barking_51.wav - Class: Chant - Confidence: 0.513
# Processed: dog_barking_0.wav - Class: Domestic animals, pets - Confidence: 0.893
# Processed: cat_46.wav - Class: Animal - Confidence: 0.764
# Processed: cat_59.wav - Class: Domestic animals, pets - Confidence: 0.615
# Processed: dog_barking_38.wav - Class: Dog - Confidence: 0.565
# Processed: cat_110.wav - Class: Cat - Confidence: 0.865
# Processed: cat_161.wav - Class: Animal - Confidence: 0.659
# Processed: cat_79.wav - Class: Silence - Confidence: 0.386
# Processed: cat_146.wav - Class: Cat - Confidence: 0.283
# Processed: dog_barking_75.wav - Class: Animal - Confidence: 0.784
# Processed: dog_barking_76.wav - Class: Dog - Confidence: 0.768
# Processed: dog_barking_44.wav - Class: Chant - Confidence: 0.280
# Processed: dog_barking_77.wav - Class: Dog - Confidence: 0.458
# Processed: cat_164.wav - Class: Inside, small room - Confidence: 0.152
# Processed: dog_barking_19.wav - Class: Animal - Confidence: 0.831
# Processed: cat_121.wav - Class: Cat - Confidence: 0.309
# Processed: cat_112.wav - Class: Cat - Confidence: 0.204
# Processed: dog_barking_37.wav - Class: Animal - Confidence: 0.232
# Processed: dog_barking_49.wav - Class: Animal - Confidence: 0.264
# Processed: dog_barking_22.wav - Class: Domestic animals, pets - Confidence: 0.756
# Processed: cat_60.wav - Class: Speech - Confidence: 0.225
# Processed: cat_90.wav - Class: Speech - Confidence: 0.231
# Processed: cat_122.wav - Class: Animal - Confidence: 0.299
# Processed: dog_barking_67.wav - Class: Animal - Confidence: 0.584
# Processed: cat_101.wav - Class: Inside, small room - Confidence: 0.149
# Processed: dog_barking_95.wav - Class: Animal - Confidence: 0.969
# Processed: dog_barking_23.wav - Class: Animal - Confidence: 0.861
# Processed: cat_80.wav - Class: Speech - Confidence: 0.435
# Processed: cat_115.wav - Class: Animal - Confidence: 0.201
# Processed: dog_barking_68.wav - Class: Dog - Confidence: 0.519
# Processed: cat_95.wav - Class: Animal - Confidence: 0.143
# Processed: cat_40.wav - Class: Animal - Confidence: 0.381
# Processed: cat_8.wav - Class: Animal - Confidence: 0.595
# Processed: dog_barking_86.wav - Class: Dog - Confidence: 0.458
# Processed: dog_barking_108.wav - Class: Crunch - Confidence: 0.312
# Processed: dog_barking_61.wav - Class: Animal - Confidence: 0.725
# Processed: cat_71.wav - Class: Animal - Confidence: 0.459
# Processed: cat_81.wav - Class: Speech - Confidence: 0.470
# Processed: cat_155.wav - Class: Animal - Confidence: 0.663
# Processed: dog_barking_39.wav - Class: Domestic animals, pets - Confidence: 0.790
# Processed: dog_barking_43.wav - Class: Chant - Confidence: 0.350
# Processed: dog_barking_31.wav - Class: Domestic animals, pets - Confidence: 0.427
# Processed: cat_39.wav - Class: Animal - Confidence: 0.619
# Processed: dog_barking_40.wav - Class: Dog - Confidence: 0.345
# Processed: cat_85.wav - Class: Animal - Confidence: 0.579
# Processed: cat_14.wav - Class: Animal - Confidence: 0.395
# Processed: cat_147.wav - Class: Animal - Confidence: 0.180
# Processed: cat_16.wav - Class: Cat - Confidence: 0.665
# Processed: dog_barking_20.wav - Class: Animal - Confidence: 0.805
# Processed: cat_102.wav - Class: Lullaby - Confidence: 0.139
# Processed: dog_barking_104.wav - Class: Animal - Confidence: 0.644
# Processed: dog_barking_87.wav - Class: Animal - Confidence: 0.872
# Processed: dog_barking_112.wav - Class: Animal - Confidence: 0.753
# Processed: cat_92.wav - Class: Speech - Confidence: 0.202
# Processed: dog_barking_8.wav - Class: Domestic animals, pets - Confidence: 0.358
# Processed: dog_barking_65.wav - Class: Animal - Confidence: 0.781
# Processed: cat_62.wav - Class: Animal - Confidence: 0.439
# Processed: cat_154.wav - Class: Animal - Confidence: 0.257
# Processed: dog_barking_54.wav - Class: Animal - Confidence: 0.596
# Processed: cat_117.wav - Class: Animal - Confidence: 0.206
# Processed: cat_82.wav - Class: Speech - Confidence: 0.473
# Processed: cat_114.wav - Class: Animal - Confidence: 0.251
# Processed: dog_barking_57.wav - Class: Dog - Confidence: 0.898
# Processed: cat_2.wav - Class: Inside, small room - Confidence: 0.353
# Processed: dog_barking_64.wav - Class: Dog - Confidence: 0.644
# Processed: dog_barking_111.wav - Class: Animal - Confidence: 0.741
# Processed: cat_12.wav - Class: Speech - Confidence: 0.183
# Processed: cat_105.wav - Class: Speech - Confidence: 0.288
# Processed: cat_30.wav - Class: Animal - Confidence: 0.347
# Processed: cat_18.wav - Class: Cat - Confidence: 0.656
# Processed: dog_barking_107.wav - Class: Vehicle - Confidence: 0.283
# Processed: cat_65.wav - Class: Animal - Confidence: 0.571
# Processed: dog_barking_69.wav - Class: Dog - Confidence: 0.391
# Processed: dog_barking_105.wav - Class: Animal - Confidence: 0.994
# Processed: dog_barking_11.wav - Class: Speech - Confidence: 0.464
# Processed: cat_138.wav - Class: Animal - Confidence: 0.503
# Processed: cat_32.wav - Class: Speech - Confidence: 0.217
# Processed: cat_97.wav - Class: Speech - Confidence: 0.425
# Processed: cat_50.wav - Class: Cat - Confidence: 0.241
# Processed: dog_barking_96.wav - Class: Animal - Confidence: 0.536
# Processed: cat_55.wav - Class: Screaming - Confidence: 0.329
# Processed: dog_barking_99.wav - Class: Animal - Confidence: 0.990
# Processed: dog_barking_35.wav - Class: Animal - Confidence: 0.743
#
# Summary Statistics:
# --------------------------------------------------
# Total files processed: 277
#
# Prediction counts:
# prediction
# Animal                    140
# Speech                     26
# Dog                        24
# Domestic animals, pets     21
# Cat                        21
# Name: count, dtype: int64
#
# Confidence score statistics:
# count    277.000000
# mean       0.500579
# std        0.247730
# min        0.102993
# 25%        0.298991
# 50%        0.463841
# 75%        0.683556
# max        0.998098
# Name: confidence, dtype: float64
# Filtered results saved to test_cat_dog_sounds.csv
# CPU times: user 19 s, sys: 1.26 s, total: 20.2 s
# Wall time: 26.4 s
